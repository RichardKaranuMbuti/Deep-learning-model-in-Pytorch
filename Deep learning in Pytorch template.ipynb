# %%
from typing import List
import re
import string
import math
import os

import torch
import torchtext
from torch.utils.data import Dataset, DataLoader
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import Vocab
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import f1_score, precision_score, recall_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd
from collections import Counter
from itertools import chain

from tqdm import tqdm
import spacy

from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize
import pickle as pkl
from argparse import Namespace
import matplotlib.ticker as plticker

# %%
# we do minor data cleaning and split the data into train and val splits.

# %%
path_to_train_csv = "/content/drive/MyDrive/NLP243/assignments/1_new/hw1_train-1.csv"
path_to_clean_train_csv = "/content/drive/MyDrive/NLP243/assignments/1_new/clean_hw1_train-1.csv"
model_save_directory = '/content/drive/MyDrive/NLP243/assignments/1_new/model/'
path_to_test_movies_csv = '/content/drive/MyDrive/NLP243/assignments/1_new/hw1_test-2.csv'

# %%
def preprocess_text(text):
  text = text.lower()
  text = re.sub(r"([.,!?])", r" \1 ", text)
  text = re.sub(r"[^a-zA-Z.,!?]+", r" ", text)
  return text

df = pd.read_csv(path_to_train_csv)
df["split"] = "train"
df.columns = ["id", "text", "labels", "split"]
df.labels = df.labels.replace(np.nan, "none", regex=True)

np.random.seed(20221002)
train_proportion = 0.80
val_proportion = 0.20

item_list = list(row.to_dict() for _, row in df.iterrows())
np.random.shuffle(item_list)

# Create split data
final_list = []

n_total = len(item_list)
n_train = int(train_proportion * n_total)
n_val = int(val_proportion * n_total)

# Give data point a split attribute
for item in item_list[:n_train]:
  item['split'] = 'train'
    
for item in item_list[n_train:n_train+n_val+1]:
  item['split'] = 'val'

# Add to final list
final_list.extend(item_list)

final_df = pd.DataFrame(final_list)
final_df.text = final_df.text.apply(preprocess_text)
final_df.to_csv(path_to_clean_train_csv)

# %%
print(final_df.tail())
# Out:
#         id                                  text  \
# 2307  1332  find movies produced by disney pixar
# 2308  1809   find movies with tom cruise in them
# 2309  1945  what pg movies are currently showing
# 2310   838                    movies from the us
# 2311   407       when did happiness get released
#
#                                        labels split
# 2307               movie.production_companies   val
# 2308                     movie.starring.actor   val
# 2309  movie.rating movie.initial_release_date   val
# 2310                            movie.country   val
# 2311               movie.initial_release_date   val

# %%
# define vocabulary, vectorizer, label indexer and dataset

class Vocabulary(object):

    def __init__(self, token_to_idx=None, add_unk=True, unk_token="<unk>"):
        """
        Args:
            token_to_idx (dict): a pre-existing map of tokens to indices
            add_unk (bool): a flag that indicates whether to add the UNK token
            unk_token (str): the UNK token to add into the Vocabulary
        """

        if token_to_idx is None:
            token_to_idx = {}
        self._token_to_idx = token_to_idx

        self._idx_to_token = {idx: token 
                              for token, idx in self._token_to_idx.items()}

        self._add_unk = add_unk
        self._unk_token = unk_token
        
        self.unk_index = -1
        if add_unk:
            self.unk_index = self.add_token(unk_token) 
        
        
    def to_serializable(self):
        """ returns a dictionary that can be serialized """
        return {'token_to_idx': self._token_to_idx, 
                'add_unk': self._add_unk, 
                'unk_token': self._unk_token}

    @classmethod
    def from_serializable(cls, contents):
        """ instantiates the Vocabulary from a serialized dictionary """
        return cls(**contents)

    def add_token(self, token):
        """Update mapping dicts based on the token.

        Args:
            token (str): the item to add into the Vocabulary
        Returns:
            index (int): the integer corresponding to the token
        """
        if token in self._token_to_idx:
            index = self._token_to_idx[token]
        else:
            index = len(self._token_to_idx)
            self._token_to_idx[token] = index
            self._idx_to_token[index] = token
        return index

    def lookup_token(self, token):
        """Retrieve the index associated with the token 
          or the UNK index if token isn't present.
        
        Args:
            token (str): the token to look up 
        Returns:
            index (int): the index corresponding to the token
        Notes:
            `unk_index` needs to be >=0 (having been added into the Vocabulary) 
              for the UNK functionality 
        """
        if self._add_unk:
            return self._token_to_idx.get(token, self.unk_index)
        else:
            return self._token_to_idx[token]

    def lookup_index(self, index):
        """Return the token associated with the index
        
        Args: 
            index (int): the index to look up
        Returns:
            token (str): the token corresponding to the index
        Raises:
            KeyError: if the index is not in the Vocabulary
        """
        if index not in self._idx_to_token:
            raise KeyError("the index (%d) is not in the Vocabulary" % index)
        return self._idx_to_token[index]

    def __str__(self):
        return "<Vocabulary(size=%d)>" % len(self)

    def __len__(self):
        return len(self._token_to_idx)


class Vectorizer(object):
    """ The Vectorizer which coordinates the Vocabularies and puts them to use"""
    def __init__(self, text_vocab):
       
        self.text_vocab = text_vocab

    def vectorize(self, text):
        """Create a collapsed one-hit vector
        
        Args:
            text (str): text
        Returns:
            one_hot (np.ndarray): the collapsed one-hot encoding
        """
        one_hot = np.zeros(len(self.text_vocab), dtype=np.float32)
        
        for token in text.split():
            if token not in string.punctuation:
                
                # use this fot one hot encoding
                one_hot[self.text_vocab.lookup_token(token)] = 1

                # # use this for count vectorizer
                # one_hot[self.text_vocab.lookup_token(token)] += 1

        return one_hot

    @classmethod
    def from_dataframe(cls, df, cutoff=1500):
        text_vocab = Vocabulary(add_unk=True)
        

        # Add top words if count > provided count
        word_counts = Counter()
        for text in df.text:
            for word in text.split():
                if word not in string.punctuation:
                    word_counts[word] += 1
        
        print(len(word_counts.most_common()))

        for word, count in dict(word_counts.most_common(cutoff)).items():
            text_vocab.add_token(word)
        
        return cls(text_vocab)

    @classmethod
    def from_serializable(cls, contents):
        text_vocab = Vocabulary.from_serializable(contents['text_vocab'])

        return cls(text_vocab=text_vocab)

    def to_serializable(self):
        return {'text_vocab': self.text_vocab.to_serializable()}


class LabelIndexer(object):
  # a standart label indexer similar to the vectorizer

    def __init__(self, labels, label2idx=None, idx2label=None):
        
        self.labels = labels
        self.n_labels = len(self.labels)
        self.label2idx = {label: i for i, label in enumerate(self.labels)} if label2idx is None else label2idx
        self.idx2label = {i:label for label, i in self.label2idx.items()} if idx2label is None else idx2label

    def encode(self, y):
        one_hot_encoded = np.zeros(self.n_labels, dtype=int)
        normalized_label = list(set([_split_label for _split_label in y.split()]))
        for _label in normalized_label:
          one_hot_encoded[self.label2idx[_label]] = 1.
        return one_hot_encoded

    def encode_batch(self, ys):
        return torch.LongTensor([self.encode(y) for y in ys])
    
    @classmethod
    def from_dataframe(cls, df):
        labels = list(set([_split_label for label in df.labels.unique().flatten() for _split_label in label.split()]))
        return cls(labels)
    
    @classmethod
    def from_serializable(cls, contents):
        labels = LabelIndexer.from_serializable(contents['labels'])
        label2idx = LabelIndexer.from_serializable(contents['label2idx'])
        idx2label = LabelIndexer.from_serializable(contents['idx2label'])
        
        return cls(labels=labels, label2idx=label2idx, idx2label=idx2label)

    def to_serializable(self):
        return {
            'labels': self.labels.to_serializable(),
            'label2idx': self.label2idx.to_serializable(),
            'idx2label': self.idx2label.to_serializable()
        }
    
    def __str__(self):
        return "<LabelIndexer(size=%d)>" % len(self)

    def __len__(self):
        return self.n_labels


class MovieDataset(Dataset):
    def __init__(self, movie_df, vectorizer, label_indexer, tfidf=False):
        """
        Args:
            movie_df (pandas.DataFrame): the dataset
            vectorizer (Vectorizer): vectorizer instantiated from dataset
        """
        self.movie_df = movie_df
        self._vectorizer = vectorizer
        self._label_indexer = label_indexer

        # self.train_df = self.movie_df[self.movie_df.split=='train']
        self.train_df = self.movie_df
        self.train_size = len(self.train_df)

        self.val_df = self.movie_df[self.movie_df.split=='val']
        self.validation_size = len(self.val_df)

        self._lookup_dict = {'train': (self.train_df, self.train_size),
                             'val': (self.val_df, self.validation_size)}

        self.set_split('train')

        self.tfidf = tfidf
        if self.tfidf:
            self._vectorizer.fit(list(self.train_df.text))

    @classmethod
    def load_dataset_and_make_vectorizer_and_label_indexer(cls, movie_csv, tfidf=False):
        """Load dataset and make a new vectorizer from scratch
        
        Args:
            review_csv (str): location of the dataset
        Returns:
            an instance of dataset
        """
        movie_df = pd.read_csv(movie_csv)

        if tfidf:
          tfidf_vectroizer = TfidfVectorizer(ngram_range=(1,2), norm=None, smooth_idf=False, use_idf=True)
          return cls(movie_df, tfidf_vectroizer, LabelIndexer.from_dataframe(movie_df), tfidf=True)
        else:
          return cls(movie_df, Vectorizer.from_dataframe(movie_df), LabelIndexer.from_dataframe(movie_df))

    def get_vectorizer(self):
        """ returns the vectorizer """
        return self._vectorizer
    
    def get_label_indexer(self):
        """ returns label indexer """
        return self._label_indexer

    def set_split(self, split="train"):
        """ selects the splits in the dataset using a column in the dataframe 
        
        Args:
            split (str): one of "train" or "val"
        """
        self._target_split = split
        self._target_df, self._target_size = self._lookup_dict[split]

    def __len__(self):
        return self._target_size

    def __getitem__(self, index):
        """the primary entry point method for PyTorch datasets
        
        Args:
            index (int): the index to the data point 
        Returns:
            a dict of the data point's features (x_data) and label (y_target)
        """
        row = self._target_df.iloc[index]

        if self.tfidf:
          text_vector = torch.FloatTensor(self._vectorizer.transform([row.text]).todense()).squeeze(0)

        else:
          text_vector = \
              self._vectorizer.vectorize(row.text)

        label_index = \
            self._label_indexer.encode(row.labels)

        return {'x_data': text_vector,
                'y_target': label_index}

    def get_num_batches(self, batch_size):
        """Given a batch size, return the number of batches in the dataset
        
        Args:
            batch_size (int)
        Returns:
            number of batches in the dataset
        """
        return len(self) // batch_size


# a function to develop 
def generate_batches(dataset, batch_size, shuffle=True,
                     drop_last=True, device="cpu"):
    """
    A generator function which wraps the PyTorch DataLoader. It will 
      ensure each tensor is on the write device location.
    """
    dataloader = DataLoader(dataset=dataset, batch_size=batch_size,
                            shuffle=shuffle, drop_last=drop_last)

    for data_dict in dataloader:
        out_data_dict = {}
        for name, tensor in data_dict.items():
            out_data_dict[name] = data_dict[name].to(device)
        yield out_data_dict

# %%
# model definition
# we try out both a one-hidden-layer MLP and two-hidden-layer MLP with different parameters for dropout, batch normalization, epochs.
# we also try out ensembling the outputs of two MLP models.
# To run in this setting first train the model 1 and model 2 separately and then combine the outputs.

class MLPMultiLabelClassifier(nn.Module):
    def __init__(self, input_size, hidden_size1, output_size, use_hidden2=True, hidden_size2=64, use_dropout=True, dropout_p1=0.2, dropout_p2=0.3, use_batch_norm=True):
        super(MLPMultiLabelClassifier, self).__init__()
        self.use_dropout = use_dropout
        self.dropout_p1=dropout_p1
        self.dropout_p2=dropout_p2
        self.use_batch_norm=use_batch_norm

        self.input_size = input_size
        self.hidden_size1 = hidden_size1
        self.use_hidden2 = use_hidden2
        self.hidden_size2 = hidden_size2
        self.output_size = output_size
        self.fci1 = nn.Linear(in_features=input_size, 
                             out_features=hidden_size1, bias=True)
        self.fc1o = nn.Linear(in_features=hidden_size1, 
                             out_features=output_size, bias=True)
        self.batch_norm1 = nn.BatchNorm1d(num_features=hidden_size1)
        self.fc12 = nn.Linear(in_features=hidden_size1, out_features=hidden_size2, bias=True)
        self.batch_norm2 = nn.BatchNorm1d(num_features=hidden_size2)
        self.fc2o = nn.Linear(in_features=hidden_size2, out_features=output_size, bias=True)
        if self.use_dropout:
          self.dropout1 = nn.Dropout(dropout_p1)
          self.dropout2 = nn.Dropout(dropout_p2)
        else:
          self.dropout1 = nn.Dropout(0.0)
          self.dropout2 = nn.Dropout(0.0)
        self.apply(self._init_weights)
    
    def _init_weights(self, module, input_size=0, output_size=0):
        # for every Linear layer in a model..
        if isinstance(module, nn.Linear):
            nn.init.kaiming_uniform_(module.weight.data, nonlinearity='relu')
            if module.bias is not None:
                module.bias.data.zero_()

    def forward(self, x_in):
        if self.use_batch_norm:
            y1_out = F.relu(self.batch_norm1(self.fci1(x_in).squeeze()))
            if self.use_hidden2:
              y2_out = self.fc12(self.dropout1(y1_out)).squeeze()
              y3_out = self.fc2o(self.dropout2(F.relu(self.batch_norm2(y2_out)))).squeeze()
              y_out = y3_out
            else:
              y2_out = self.fc1o(self.dropout1(y1_out)).squeeze()
              y_out = y2_out
        else:
            y1_out = F.relu(self.fci1(x_in).squeeze())
            if self.use_hidden2:
              y2_out = self.fc12(self.dropout1(y1_out)).squeeze()
              y3_out = self.fc2o(self.dropout2(F.relu(y2_out))).squeeze()
              y_out = y3_out
            else:
              y2_out = self.fc1o(self.dropout1(y1_out)).squeeze()
              y_out = y2_out
        return y_out

# %%
# best performing two-hidden-layer MLP had the following parameters

model_number = '2'
args = Namespace(
    # Data and path information
    movie_csv=path_to_clean_train_csv,
    save_dir=model_save_directory,
    model_number=model_number,
    dataset_file='{}/{}/dataset.pkl'.format(model_save_directory, model_number),
    vectroizer_file='{}/{}/vectroizer.pkl'.format(model_save_directory, model_number),
    label_indexer_file='{}/{}/label_indexer.pkl'.format(model_save_directory, model_number),
    model_state_file='{}/{}/model.pth'.format(model_save_directory, model_number),
    train_state_file='{}/{}/train_state.pkl'.format(model_save_directory, model_number),
    submission_path = '{}/{}/submission.csv'.format(model_save_directory, model_number),
    tfidf=False,
    # Training hyperparameters
    hidden_size1=1024,
    use_hidden2=True,
    hidden_size2=1024,
    batch_size=16,
    use_dropout=True,
    dropout_p1=0.3,
    dropout_p2=0.2,
    use_batch_norm=True,
    learning_rate=0.001,
    num_epochs=100
)

if not torch.cuda.is_available():
    args.cuda = False
args.device = torch.device("cuda" if args.cuda else "cpu")


# training state
def make_train_state(args):
    return {'epoch_index': 0,
            'train_loss': [],
            'train_all_true_labels': [],
            'train_all_pred_labels': [],
            'train_classification_report': [],
            'val_loss': [],
            'val_all_true_labels': [],
            'val_all_pred_labels': [],
            'val_classification_report': [],
            'test_loss': [],
            'test_classification_report': []}
train_state = make_train_state(args)

# instantiate dataset and vectorizer

dataset = MovieDataset.load_dataset_and_make_vectorizer_and_label_indexer(args.movie_csv, tfidf=args.tfidf)
vectorizer = dataset.get_vectorizer()
label_indexer = dataset.get_label_indexer()

if not os.path.exists(args.save_dir):
    os.mkdir(args.save_dir)
if not os.path.exists(os.path.join(args.save_dir, args.model_number)):
    os.mkdir(os.path.join(args.save_dir, args.model_number))
with open(args.dataset_file, "wb") as output_file:
    pkl.dump(dataset, output_file)
with open(args.vectroizer_file, "wb") as output_file:
    pkl.dump(vectorizer, output_file)
with open(args.label_indexer_file, "wb") as output_file:
    pkl.dump(label_indexer, output_file)

labels = [label_indexer.idx2label[_idx] for _idx in range(len(label_indexer))]

# model
classifier = MLPMultiLabelClassifier(input_size=len(vectorizer.text_vocab) if not args.tfidf else len(vectorizer.get_feature_names_out()), hidden_size1=args.hidden_size1, output_size=len(label_indexer), use_hidden2=args.use_hidden2, hidden_size2=args.hidden_size2, use_dropout=args.use_dropout, dropout_p1=args.dropout_p1, dropout_p2=args.dropout_p2, use_batch_norm=args.use_batch_norm)
classifier = classifier.to(args.device)

# instantiate loss and optimizer
loss_func = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(classifier.parameters(), lr=args.learning_rate, weight_decay=1e-4)

for epoch_index in range(args.num_epochs):
    train_state['epoch_index'] = epoch_index

    # generate batches and iterate over training dataset
    dataset.set_split('train')
    batch_generator = generate_batches(dataset, 
                                       batch_size=args.batch_size, 
                                       device=args.device)
    running_loss = 0.0

    batch_wise_true_labels = []
    batch_wise_predictions = []

    classifier.train()

    for batch_index, batch_dict in enumerate(batch_generator):

        # 1: zero gradients
        optimizer.zero_grad()

        # 2: get model predictions
        y_pred = classifier(x_in=batch_dict['x_data'].float())

        # 3: get loss
        loss = loss_func(y_pred, batch_dict['y_target'].squeeze().float())
        loss_batch = loss.item()
        running_loss += (loss_batch - running_loss) / (batch_index + 1)

        # 4: get gradients
        loss.backward()

        # optional: clip the grad norm
        nn.utils.clip_grad_norm_(classifier.parameters(), 3.0)

        # step 5. use optimizer to take gradient step
        optimizer.step()

        # metrics

        y_pred_normalized = F.sigmoid(y_pred)
        y_pred_labels = y_pred_normalized >= 0.5
        
        batch_wise_true_labels.append(batch_dict['y_target'].tolist())
        batch_wise_predictions.append(y_pred_labels.tolist())

    train_state['train_loss'].append(running_loss)
    
    all_true_labels = list(chain.from_iterable(batch_wise_true_labels))
    all_pred_labels = list(chain.from_iterable(batch_wise_predictions))
    train_state['train_all_true_labels'].append(all_true_labels)
    train_state['train_all_pred_labels'].append(all_pred_labels)

    # generate a classification report
    print("Train classification report after epoch: {}".format(train_state['epoch_index']))
    train_classification_report = classification_report(all_true_labels, all_pred_labels, target_names=labels, output_dict=True)
    train_state['train_classification_report'].append(train_classification_report)
    print(classification_report(all_true_labels, all_pred_labels, target_names=labels))

    # generate batches and iterate over validation dataset
    dataset.set_split('val')
    batch_generator = generate_batches(dataset, 
                                       batch_size=args.batch_size, 
                                       device=args.device)
    running_loss = 0.

    classifier.eval()

    batch_wise_true_labels = []
    batch_wise_predictions = []

    for batch_index, batch_dict in enumerate(batch_generator):

        # 1: get model predictions
        y_pred = classifier(x_in=batch_dict['x_data'].float())

        # loss
        loss = loss_func(y_pred, batch_dict['y_target'].squeeze().float())
        loss_batch = loss.item()
        running_loss += (loss_batch - running_loss) / (batch_index + 1)

        # metrics

        y_pred_normalized = F.sigmoid(y_pred)
        y_pred_labels = y_pred_normalized >= 0.5
        
        batch_wise_true_labels.append(batch_dict['y_target'].tolist())
        batch_wise_predictions.append(y_pred_labels.tolist())

    train_state['val_loss'].append(running_loss)
    
    all_true_labels = list(chain.from_iterable(batch_wise_true_labels))
    all_pred_labels = list(chain.from_iterable(batch_wise_predictions))
    train_state['val_all_true_labels'].append(all_true_labels)
    train_state['val_all_pred_labels'].append(all_pred_labels)

    # generate a classification report
    print("Val classification report after epoch: {}".format(train_state['epoch_index']))
    val_classification_report = classification_report(all_true_labels, all_pred_labels, target_names=labels, output_dict=True)
    train_state['val_classification_report'].append(val_classification_report)
    print(classification_report(all_true_labels, all_pred_labels, target_names=labels))

# save model state dict
classifier_state_dict = classifier.state_dict()
torch.save(classifier_state_dict, args.model_state_file)

# save train state
with open(args.train_state_file, "wb") as output_file:
  pkl.dump(train_state, output_file)

# plot training and validation loss curves
all_train_running_losses = list(chain(train_state['train_loss']))
all_valid_running_losses = list(chain(train_state['val_loss']))

all_train_f1 = [_x['weighted avg']['f1-score'] for _x in train_state['train_classification_report']]
all_val_f1 = [_x['weighted avg']['f1-score'] for _x in train_state['val_classification_report']]

train_epoch_idx = range(len(train_state['train_loss']))
valid_epoch_idx = range(len(train_state['val_loss']))

plt.rcParams["figure.figsize"] = (20, 10)
sns.set_style('whitegrid')
locx = plticker.MultipleLocator(base=2.0)
locy = plticker.MultipleLocator(base=0.01)
axes = sns.lineplot(train_epoch_idx, all_train_running_losses, legend='brief', label='Train Loss')
axes.xaxis.set_major_locator(locx)
axes.yaxis.set_major_locator(locy)
sns.lineplot(valid_epoch_idx, all_valid_running_losses, legend='brief', label='Validation Loss')
plt.show()
# Out:
# 1132
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train classification report after epoch: 0
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       0.73      0.53      0.61       355
# movie.initial_release_date       0.91      0.59      0.71       188
#        movie.gross_revenue       0.29      0.15      0.20        34
#               movie.rating       0.93      0.73      0.82       210
#             movie.language       0.76      0.54      0.63       218
#                movie.music       0.02      0.33      0.03         3
#                movie.genre       0.62      0.30      0.41       129
#            movie.locations       0.00      0.00      0.00         3
#             movie.subjects       0.71      0.38      0.49        93
#       person.date_of_birth       0.06      0.17      0.09         6
# movie.production_companies       0.41      0.26      0.32        92
#          movie.produced_by       0.71      0.61      0.66       174
#          movie.directed_by       0.87      0.67      0.76       345
#                       none       0.74      0.61      0.67       318
#              movie.country       0.65      0.46      0.54       223
#   movie.starring.character       0.05      0.05      0.05        22
#                  gr.amount       0.00      0.00      0.00         5
#               actor.gender       0.00      0.00      0.00         9
#     movie.estimated_budget       0.55      0.67      0.61        79
#
#                  micro avg       0.70      0.54      0.61      2506
#                  macro avg       0.47      0.37      0.40      2506
#               weighted avg       0.73      0.54      0.62      2506
#                samples avg       0.56      0.56      0.55      2506
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Val classification report after epoch: 0
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       1.00      0.95      0.97        75
# movie.initial_release_date       1.00      0.90      0.95        42
#        movie.gross_revenue       0.86      0.86      0.86         7
#               movie.rating       1.00      0.95      0.98        42
#             movie.language       0.97      1.00      0.99        37
#                movie.music       0.00      0.00      0.00         0
#                movie.genre       0.87      0.93      0.90        29
#            movie.locations       0.00      0.00      0.00         0
#             movie.subjects       1.00      0.89      0.94         9
#       person.date_of_birth       0.00      0.00      0.00         1
# movie.production_companies       0.93      0.93      0.93        14
#          movie.produced_by       0.96      0.96      0.96        28
#          movie.directed_by       0.97      0.97      0.97        78
#                       none       0.87      0.95      0.91        65
#              movie.country       0.95      0.93      0.94        44
#   movie.starring.character       1.00      0.80      0.89         5
#                  gr.amount       0.00      0.00      0.00         0
#               actor.gender       1.00      0.75      0.86         4
#     movie.estimated_budget       1.00      1.00      1.00        16
#
#                  micro avg       0.96      0.95      0.95       496
#                  macro avg       0.76      0.73      0.74       496
#               weighted avg       0.96      0.95      0.95       496
#                samples avg       0.95      0.95      0.95       496
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train classification report after epoch: 1
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       0.90      0.86      0.88       352
# movie.initial_release_date       0.98      0.86      0.91       189
#        movie.gross_revenue       0.96      0.68      0.79        34
#               movie.rating       0.98      0.92      0.95       210
#             movie.language       0.98      0.91      0.94       219
#                movie.music       0.00      0.00      0.00         3
#                movie.genre       0.92      0.75      0.83       129
#            movie.locations       0.00      0.00      0.00         3
#             movie.subjects       0.99      0.87      0.93        94
#       person.date_of_birth       0.00      0.00      0.00         6
# movie.production_companies       0.86      0.68      0.76        93
#          movie.produced_by       0.96      0.89      0.92       174
#          movie.directed_by       0.94      0.89      0.91       345
#                       none       0.91      0.81      0.86       318
#              movie.country       0.91      0.82      0.86       223
#   movie.starring.character       0.92      0.55      0.69        22
#                  gr.amount       1.00      0.20      0.33         5
#               actor.gender       0.67      0.22      0.33         9
#     movie.estimated_budget       0.97      0.90      0.93        79
#
#                  micro avg       0.94      0.84      0.89      2507
#                  macro avg       0.78      0.62      0.68      2507
#               weighted avg       0.93      0.84      0.88      2507
#                samples avg       0.85      0.85      0.85      2507
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Val classification report after epoch: 1
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       1.00      1.00      1.00        78
# movie.initial_release_date       0.95      1.00      0.98        42
#        movie.gross_revenue       1.00      1.00      1.00         6
#               movie.rating       1.00      1.00      1.00        39
#             movie.language       0.97      1.00      0.99        36
#                movie.music       0.00      0.00      0.00         0
#                movie.genre       0.94      0.97      0.95        31
#            movie.locations       0.00      0.00      0.00         0
#             movie.subjects       1.00      1.00      1.00         9
#       person.date_of_birth       1.00      1.00      1.00         1
# movie.production_companies       1.00      1.00      1.00        14
#          movie.produced_by       1.00      0.96      0.98        26
#          movie.directed_by       0.94      1.00      0.97        78
#                       none       0.98      0.96      0.97        67
#              movie.country       0.96      1.00      0.98        43
#   movie.starring.character       0.83      1.00      0.91         5
#                  gr.amount       0.00      0.00      0.00         0
#               actor.gender       1.00      1.00      1.00         4
#     movie.estimated_budget       0.94      1.00      0.97        16
#
#                  micro avg       0.97      0.99      0.98       495
#                  macro avg       0.82      0.84      0.83       495
#               weighted avg       0.97      0.99      0.98       495
#                samples avg       0.98      0.99      0.98       495
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train classification report after epoch: 2
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       0.97      0.94      0.95       354
# movie.initial_release_date       0.97      0.94      0.95       189
#        movie.gross_revenue       1.00      0.94      0.97        34
#               movie.rating       1.00      0.99      0.99       210
#             movie.language       0.98      0.96      0.97       217
#                movie.music       0.00      0.00      0.00         3
#                movie.genre       0.98      0.88      0.93       129
#            movie.locations       1.00      0.67      0.80         3
#             movie.subjects       1.00      0.96      0.98        94
#       person.date_of_birth       1.00      0.67      0.80         6
# movie.production_companies       0.93      0.86      0.89        93
#          movie.produced_by       0.97      0.95      0.96       174
#          movie.directed_by       0.96      0.93      0.95       346
#                       none       0.92      0.89      0.91       317
#              movie.country       0.97      0.90      0.94       221
#   movie.starring.character       0.87      0.59      0.70        22
#                  gr.amount       1.00      0.40      0.57         5
#               actor.gender       1.00      0.78      0.88         9
#     movie.estimated_budget       0.99      0.96      0.97        79
#
#                  micro avg       0.97      0.92      0.94      2505
#                  macro avg       0.92      0.80      0.85      2505
#               weighted avg       0.97      0.92      0.94      2505
#                samples avg       0.93      0.93      0.93      2505
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Val classification report after epoch: 2
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       0.99      1.00      0.99        77
# movie.initial_release_date       1.00      1.00      1.00        41
#        movie.gross_revenue       1.00      1.00      1.00         7
#               movie.rating       1.00      1.00      1.00        41
#             movie.language       1.00      1.00      1.00        37
#                movie.music       0.00      0.00      0.00         0
#                movie.genre       1.00      1.00      1.00        30
#            movie.locations       0.00      0.00      0.00         0
#             movie.subjects       1.00      1.00      1.00         9
#       person.date_of_birth       1.00      1.00      1.00         1
# movie.production_companies       0.93      1.00      0.97        14
#          movie.produced_by       0.90      0.96      0.93        28
#          movie.directed_by       1.00      1.00      1.00        76
#                       none       0.98      0.97      0.98        66
#              movie.country       1.00      1.00      1.00        44
#   movie.starring.character       0.83      1.00      0.91         5
#                  gr.amount       0.00      0.00      0.00         0
#               actor.gender       1.00      1.00      1.00         3
#     movie.estimated_budget       1.00      1.00      1.00        16
#
#                  micro avg       0.99      0.99      0.99       495
#                  macro avg       0.82      0.84      0.83       495
#               weighted avg       0.99      0.99      0.99       495
#                samples avg       0.99      0.99      0.99       495
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train classification report after epoch: 3
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       0.99      0.98      0.98       353
# movie.initial_release_date       0.99      0.95      0.97       189
#        movie.gross_revenue       1.00      0.94      0.97        34
#               movie.rating       1.00      0.99      1.00       208
#             movie.language       1.00      0.98      0.99       220
#                movie.music       1.00      0.33      0.50         3
#                movie.genre       0.99      0.95      0.97       128
#            movie.locations       1.00      0.67      0.80         3
#             movie.subjects       1.00      0.99      0.99        94
#       person.date_of_birth       1.00      1.00      1.00         6
# movie.production_companies       0.98      0.96      0.97        93
#          movie.produced_by       0.97      0.97      0.97       175
#          movie.directed_by       0.98      0.95      0.96       346
#                       none       0.96      0.92      0.94       318
#              movie.country       0.96      0.94      0.95       223
#   movie.starring.character       1.00      0.73      0.84        22
#                  gr.amount       1.00      0.60      0.75         5
#               actor.gender       1.00      0.89      0.94         9
#     movie.estimated_budget       1.00      1.00      1.00        78
#
#                  micro avg       0.98      0.96      0.97      2507
#                  macro avg       0.99      0.88      0.92      2507
#               weighted avg       0.98      0.96      0.97      2507
#                samples avg       0.96      0.96      0.96      2507
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Val classification report after epoch: 3
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       0.99      1.00      0.99        78
# movie.initial_release_date       1.00      1.00      1.00        42
#        movie.gross_revenue       1.00      1.00      1.00         7
#               movie.rating       1.00      1.00      1.00        39
#             movie.language       1.00      1.00      1.00        37
#                movie.music       0.00      0.00      0.00         0
#                movie.genre       1.00      1.00      1.00        29
#            movie.locations       0.00      0.00      0.00         0
#             movie.subjects       1.00      1.00      1.00         9
#       person.date_of_birth       1.00      1.00      1.00         1
# movie.production_companies       0.94      1.00      0.97        15
#          movie.produced_by       1.00      0.97      0.98        29
#          movie.directed_by       0.99      1.00      0.99        76
#                       none       1.00      0.97      0.98        66
#              movie.country       1.00      1.00      1.00        43
#   movie.starring.character       1.00      1.00      1.00         5
#                  gr.amount       0.00      0.00      0.00         0
#               actor.gender       1.00      1.00      1.00         4
#     movie.estimated_budget       1.00      1.00      1.00        15
#
#                  micro avg       0.99      0.99      0.99       495
#                  macro avg       0.84      0.84      0.84       495
#               weighted avg       0.99      0.99      0.99       495
#                samples avg       0.99      0.99      0.99       495
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train classification report after epoch: 4
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       0.99      0.95      0.97       353
# movie.initial_release_date       0.99      0.98      0.99       189
#        movie.gross_revenue       1.00      1.00      1.00        34
#               movie.rating       1.00      1.00      1.00       210
#             movie.language       0.99      0.98      0.98       218
#                movie.music       1.00      0.67      0.80         3
#                movie.genre       1.00      1.00      1.00       127
#            movie.locations       1.00      0.67      0.80         3
#             movie.subjects       1.00      1.00      1.00        94
#       person.date_of_birth       1.00      1.00      1.00         6
# movie.production_companies       0.99      0.98      0.98        93
#          movie.produced_by       0.99      0.96      0.97       175
#          movie.directed_by       0.98      0.98      0.98       346
#                       none       0.95      0.95      0.95       318
#              movie.country       0.96      0.96      0.96       222
#   movie.starring.character       0.90      0.86      0.88        22
#                  gr.amount       1.00      0.80      0.89         5
#               actor.gender       1.00      1.00      1.00         9
#     movie.estimated_budget       0.99      0.99      0.99        79
#
#                  micro avg       0.98      0.97      0.98      2506
#                  macro avg       0.98      0.93      0.95      2506
#               weighted avg       0.98      0.97      0.98      2506
#                samples avg       0.97      0.97      0.97      2506
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Val classification report after epoch: 4
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       1.00      1.00      1.00        78
# movie.initial_release_date       1.00      1.00      1.00        42
#        movie.gross_revenue       1.00      1.00      1.00         6
#               movie.rating       1.00      1.00      1.00        41
#             movie.language       1.00      1.00      1.00        37
#                movie.music       0.00      0.00      0.00         0
#                movie.genre       1.00      1.00      1.00        31
#            movie.locations       0.00      0.00      0.00         0
#             movie.subjects       1.00      1.00      1.00         9
#       person.date_of_birth       1.00      1.00      1.00         1
# movie.production_companies       1.00      0.86      0.92        14
#          movie.produced_by       0.93      1.00      0.97        28
#          movie.directed_by       0.99      1.00      0.99        76
#                       none       0.98      0.97      0.98        67
#              movie.country       1.00      1.00      1.00        42
#   movie.starring.character       1.00      1.00      1.00         5
#                  gr.amount       0.00      0.00      0.00         0
#               actor.gender       1.00      1.00      1.00         4
#     movie.estimated_budget       1.00      1.00      1.00        15
#
#                  micro avg       0.99      0.99      0.99       496
#                  macro avg       0.84      0.83      0.83       496
#               weighted avg       0.99      0.99      0.99       496
#                samples avg       0.99      0.99      0.99       496
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train classification report after epoch: 5
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       0.96      0.96      0.96       354
# movie.initial_release_date       0.99      0.95      0.97       189
#        movie.gross_revenue       1.00      1.00      1.00        34
#               movie.rating       1.00      1.00      1.00       210
#             movie.language       1.00      0.98      0.99       220
#                movie.music       1.00      0.67      0.80         3
#                movie.genre       1.00      0.98      0.99       128
#            movie.locations       1.00      1.00      1.00         3
#             movie.subjects       1.00      0.99      0.99        94
#       person.date_of_birth       1.00      0.83      0.91         6
# movie.production_companies       0.97      0.96      0.96        92
#          movie.produced_by       0.98      0.98      0.98       175
#          movie.directed_by       0.99      0.99      0.99       345
#                       none       0.97      0.96      0.97       317
#              movie.country       0.97      0.97      0.97       223
#   movie.starring.character       0.95      0.86      0.90        22
#                  gr.amount       1.00      0.60      0.75         5
#               actor.gender       1.00      0.89      0.94         9
#     movie.estimated_budget       1.00      0.99      0.99        78
#
#                  micro avg       0.98      0.97      0.98      2507
#                  macro avg       0.99      0.92      0.95      2507
#               weighted avg       0.98      0.97      0.98      2507
#                samples avg       0.97      0.98      0.97      2507
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Val classification report after epoch: 5
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       1.00      1.00      1.00        75
# movie.initial_release_date       1.00      0.98      0.99        42
#        movie.gross_revenue       1.00      1.00      1.00         7
#               movie.rating       1.00      1.00      1.00        42
#             movie.language       1.00      1.00      1.00        37
#                movie.music       0.00      0.00      0.00         0
#                movie.genre       1.00      1.00      1.00        29
#            movie.locations       0.00      0.00      0.00         0
#             movie.subjects       1.00      1.00      1.00         9
#       person.date_of_birth       1.00      1.00      1.00         1
# movie.production_companies       1.00      1.00      1.00        14
#          movie.produced_by       1.00      1.00      1.00        29
#          movie.directed_by       1.00      1.00      1.00        77
#                       none       0.97      1.00      0.98        64
#              movie.country       1.00      1.00      1.00        45
#   movie.starring.character       1.00      1.00      1.00         5
#                  gr.amount       0.00      0.00      0.00         0
#               actor.gender       1.00      1.00      1.00         4
#     movie.estimated_budget       1.00      1.00      1.00        16
#
#                  micro avg       1.00      1.00      1.00       496
#                  macro avg       0.84      0.84      0.84       496
#               weighted avg       1.00      1.00      1.00       496
#                samples avg       1.00      1.00      1.00       496
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train classification report after epoch: 6
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       0.99      0.99      0.99       353
# movie.initial_release_date       0.98      0.97      0.98       188
#        movie.gross_revenue       1.00      0.91      0.95        34
#               movie.rating       1.00      1.00      1.00       210
#             movie.language       1.00      0.99      0.99       219
#                movie.music       1.00      0.67      0.80         3
#                movie.genre       1.00      0.98      0.99       129
#            movie.locations       1.00      0.67      0.80         3
#             movie.subjects       1.00      1.00      1.00        94
#       person.date_of_birth       1.00      1.00      1.00         6
# movie.production_companies       1.00      0.98      0.99        92
#          movie.produced_by       0.99      0.98      0.98       175
#          movie.directed_by       0.99      0.99      0.99       346
#                       none       0.98      0.97      0.97       319
#              movie.country       0.99      0.96      0.97       220
#   movie.starring.character       1.00      1.00      1.00        22
#                  gr.amount       1.00      0.80      0.89         5
#               actor.gender       1.00      0.78      0.88         9
#     movie.estimated_budget       0.97      0.99      0.98        79
#
#                  micro avg       0.99      0.98      0.98      2506
#                  macro avg       0.99      0.93      0.96      2506
#               weighted avg       0.99      0.98      0.98      2506
#                samples avg       0.98      0.98      0.98      2506
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Val classification report after epoch: 6
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       1.00      1.00      1.00        77
# movie.initial_release_date       1.00      0.93      0.96        40
#        movie.gross_revenue       1.00      1.00      1.00         6
#               movie.rating       1.00      1.00      1.00        39
#             movie.language       1.00      1.00      1.00        36
#                movie.music       0.00      0.00      0.00         0
#                movie.genre       1.00      1.00      1.00        31
#            movie.locations       0.00      0.00      0.00         0
#             movie.subjects       1.00      1.00      1.00         9
#       person.date_of_birth       1.00      1.00      1.00         1
# movie.production_companies       1.00      1.00      1.00        15
#          movie.produced_by       1.00      1.00      1.00        28
#          movie.directed_by       1.00      1.00      1.00        77
#                       none       0.99      0.99      0.99        68
#              movie.country       1.00      1.00      1.00        45
#   movie.starring.character       1.00      1.00      1.00         5
#                  gr.amount       0.00      0.00      0.00         0
#               actor.gender       1.00      1.00      1.00         4
#     movie.estimated_budget       1.00      1.00      1.00        15
#
#                  micro avg       1.00      0.99      0.99       496
#                  macro avg       0.84      0.84      0.84       496
#               weighted avg       1.00      0.99      0.99       496
#                samples avg       1.00      0.99      0.99       496
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train classification report after epoch: 7
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       0.98      0.97      0.98       352
# movie.initial_release_date       0.99      0.95      0.97       189
#        movie.gross_revenue       0.97      0.97      0.97        34
#               movie.rating       1.00      0.99      0.99       210
#             movie.language       1.00      1.00      1.00       220
#                movie.music       1.00      1.00      1.00         3
#                movie.genre       0.98      0.98      0.98       129
#            movie.locations       1.00      0.67      0.80         3
#             movie.subjects       1.00      1.00      1.00        94
#       person.date_of_birth       1.00      1.00      1.00         6
# movie.production_companies       0.96      0.97      0.96        92
#          movie.produced_by       0.99      0.98      0.99       175
#          movie.directed_by       0.97      0.96      0.96       346
#                       none       0.96      0.94      0.95       316
#              movie.country       0.99      0.99      0.99       223
#   movie.starring.character       1.00      0.86      0.93        22
#                  gr.amount       1.00      1.00      1.00         5
#               actor.gender       1.00      1.00      1.00         9
#     movie.estimated_budget       0.99      0.99      0.99        79
#
#                  micro avg       0.98      0.97      0.98      2507
#                  macro avg       0.99      0.96      0.97      2507
#               weighted avg       0.98      0.97      0.98      2507
#                samples avg       0.97      0.97      0.97      2507
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Val classification report after epoch: 7
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       1.00      1.00      1.00        78
# movie.initial_release_date       1.00      0.97      0.99        40
#        movie.gross_revenue       1.00      1.00      1.00         7
#               movie.rating       1.00      1.00      1.00        42
#             movie.language       1.00      1.00      1.00        37
#                movie.music       0.00      0.00      0.00         0
#                movie.genre       1.00      1.00      1.00        29
#            movie.locations       0.00      0.00      0.00         0
# ...
#
#                  micro avg       0.99      0.98      0.98      2507
#                  macro avg       1.00      0.90      0.93      2507
#               weighted avg       0.99      0.98      0.98      2507
#                samples avg       0.98      0.98      0.98      2507
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Val classification report after epoch: 97
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       1.00      1.00      1.00        76
# movie.initial_release_date       1.00      1.00      1.00        42
#        movie.gross_revenue       1.00      1.00      1.00         7
#               movie.rating       1.00      1.00      1.00        41
#             movie.language       1.00      1.00      1.00        37
#                movie.music       0.00      0.00      0.00         0
#                movie.genre       1.00      1.00      1.00        31
#            movie.locations       0.00      0.00      0.00         0
#             movie.subjects       1.00      1.00      1.00         8
#       person.date_of_birth       1.00      1.00      1.00         1
# movie.production_companies       1.00      1.00      1.00        14
#          movie.produced_by       1.00      1.00      1.00        28
#          movie.directed_by       1.00      1.00      1.00        79
#                       none       1.00      1.00      1.00        64
#              movie.country       1.00      1.00      1.00        45
#   movie.starring.character       1.00      1.00      1.00         4
#                  gr.amount       0.00      0.00      0.00         0
#               actor.gender       1.00      1.00      1.00         4
#     movie.estimated_budget       1.00      1.00      1.00        15
#
#                  micro avg       1.00      1.00      1.00       496
#                  macro avg       0.84      0.84      0.84       496
#               weighted avg       1.00      1.00      1.00       496
#                samples avg       1.00      1.00      1.00       496
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train classification report after epoch: 98
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       0.99      0.99      0.99       354
# movie.initial_release_date       1.00      0.98      0.99       189
#        movie.gross_revenue       1.00      0.97      0.99        34
#               movie.rating       1.00      1.00      1.00       210
#             movie.language       0.99      1.00      0.99       220
#                movie.music       1.00      1.00      1.00         3
#                movie.genre       0.99      0.96      0.98       128
#            movie.locations       1.00      0.67      0.80         3
#             movie.subjects       1.00      0.98      0.99        94
#       person.date_of_birth       1.00      1.00      1.00         6
# movie.production_companies       0.98      0.97      0.97        93
#          movie.produced_by       0.99      0.97      0.98       173
#          movie.directed_by       0.99      0.99      0.99       344
#                       none       0.98      0.97      0.98       319
#              movie.country       1.00      0.98      0.99       222
#   movie.starring.character       1.00      0.91      0.95        22
#                  gr.amount       1.00      0.60      0.75         5
#               actor.gender       1.00      1.00      1.00         9
#     movie.estimated_budget       1.00      1.00      1.00        79
#
#                  micro avg       0.99      0.98      0.99      2507
#                  macro avg       1.00      0.94      0.97      2507
#               weighted avg       0.99      0.98      0.99      2507
#                samples avg       0.98      0.98      0.98      2507
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Val classification report after epoch: 98
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       1.00      1.00      1.00        77
# movie.initial_release_date       1.00      1.00      1.00        42
#        movie.gross_revenue       1.00      1.00      1.00         7
#               movie.rating       1.00      1.00      1.00        41
#             movie.language       1.00      1.00      1.00        35
#                movie.music       0.00      0.00      0.00         0
#                movie.genre       1.00      1.00      1.00        31
#            movie.locations       0.00      0.00      0.00         0
#             movie.subjects       1.00      1.00      1.00         9
#       person.date_of_birth       1.00      1.00      1.00         1
# movie.production_companies       1.00      1.00      1.00        15
#          movie.produced_by       1.00      1.00      1.00        28
#          movie.directed_by       1.00      1.00      1.00        77
#                       none       1.00      1.00      1.00        65
#              movie.country       1.00      1.00      1.00        44
#   movie.starring.character       1.00      1.00      1.00         5
#                  gr.amount       0.00      0.00      0.00         0
#               actor.gender       1.00      1.00      1.00         4
#     movie.estimated_budget       1.00      1.00      1.00        15
#
#                  micro avg       1.00      1.00      1.00       496
#                  macro avg       0.84      0.84      0.84       496
#               weighted avg       1.00      1.00      1.00       496
#                samples avg       1.00      1.00      1.00       496
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train classification report after epoch: 99
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       0.99      0.99      0.99       352
# movie.initial_release_date       1.00      0.99      0.99       189
#        movie.gross_revenue       1.00      0.97      0.99        34
#               movie.rating       1.00      1.00      1.00       211
#             movie.language       1.00      0.99      1.00       219
#                movie.music       1.00      0.33      0.50         3
#                movie.genre       0.99      0.98      0.98       128
#            movie.locations       1.00      1.00      1.00         3
#             movie.subjects       1.00      0.99      0.99        93
#       person.date_of_birth       1.00      0.67      0.80         6
# movie.production_companies       0.99      0.97      0.98        93
#          movie.produced_by       0.99      0.99      0.99       173
#          movie.directed_by       0.99      1.00      1.00       346
#                       none       0.98      0.99      0.99       319
#              movie.country       1.00      0.99      0.99       222
#   movie.starring.character       1.00      0.91      0.95        22
#                  gr.amount       1.00      1.00      1.00         5
#               actor.gender       1.00      0.89      0.94         9
#     movie.estimated_budget       1.00      0.97      0.99        79
#
#                  micro avg       0.99      0.99      0.99      2506
#                  macro avg       1.00      0.93      0.95      2506
#               weighted avg       0.99      0.99      0.99      2506
#                samples avg       0.99      0.99      0.99      2506
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Val classification report after epoch: 99
#                             precision    recall  f1-score   support
#
#       movie.starring.actor       1.00      1.00      1.00        77
# movie.initial_release_date       1.00      1.00      1.00        41
#        movie.gross_revenue       1.00      1.00      1.00         7
#               movie.rating       1.00      1.00      1.00        42
#             movie.language       1.00      1.00      1.00        37
#                movie.music       0.00      0.00      0.00         0
#                movie.genre       1.00      1.00      1.00        29
#            movie.locations       0.00      0.00      0.00         0
#             movie.subjects       1.00      1.00      1.00         9
#       person.date_of_birth       1.00      1.00      1.00         1
# movie.production_companies       1.00      1.00      1.00        14
#          movie.produced_by       1.00      1.00      1.00        29
#          movie.directed_by       1.00      1.00      1.00        78
#                       none       1.00      1.00      1.00        65
#              movie.country       1.00      1.00      1.00        43
#   movie.starring.character       1.00      1.00      1.00         5
#                  gr.amount       0.00      0.00      0.00         0
#               actor.gender       1.00      1.00      1.00         4
#     movie.estimated_budget       1.00      1.00      1.00        14
#
#                  micro avg       1.00      1.00      1.00       495
#                  macro avg       0.84      0.84      0.84       495
#               weighted avg       1.00      1.00      1.00       495
#                samples avg       1.00      1.00      1.00       495
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# plot for training and validation F1

all_train_f1 = [_x['weighted avg']['f1-score'] for _x in train_state['train_classification_report']]
all_val_f1 = [_x['weighted avg']['f1-score'] for _x in train_state['val_classification_report']]
sns.lineplot(train_epoch_idx, all_train_f1, legend='brief', label='Train weighted avg F1')

sns.lineplot(valid_epoch_idx, all_val_f1, legend='brief', label='Validation weighted avg F1')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# predict labels for test set
def predict_labels(text, classifier, vectorizer, label_indexer,
                   threshold=0.5, tfidf=False):
    """Predict the labels for the movie text

    Args:
        text: the text of the movie
        classifier: the trained model
        vectorizer: the corresponding vectorizer
        threshold: the threshold for positive and negative
    """

    processed_text = preprocess_text(text)
    if tfidf:
      vectorized_text = torch.FloatTensor(vectorizer.transform([processed_text]).todense()).squeeze(0)
      y_pred = classifier(vectorized_text)
    else:
      vectorized_text = torch.tensor(vectorizer.vectorize(processed_text))
      # made a mistake of using squeeze in the models so the model doesnt work for a batch size of 1, hence have to pass two texts, so 
      reshaped_vectorized_text = torch.reshape(vectorized_text, (1, vectorized_text.shape[0]))
      y_pred = classifier(torch.cat((reshaped_vectorized_text, reshaped_vectorized_text), dim=0).squeeze())[0]
    y_pred_normalized = F.sigmoid(y_pred)
    y_pred_labels = y_pred_normalized >= threshold
    labels = [label_indexer.idx2label[_idx] for _idx, value in enumerate(y_pred_labels.tolist()) if value]
    return labels


test_movies_df = pd.read_csv(path_to_test_movies_csv)
test_movies_df.columns = ["id", "text"]
all_text_labels = []
all_text_ids = []
for _idx, _text in enumerate(test_movies_df.text, 0):
    labels = predict_labels(text=_text, classifier=classifier, vectorizer=vectorizer, label_indexer=label_indexer, threshold=0.5)
    labels = ["" if _label == 'none' else _label for _label in labels]
    formatted_labels = " ".join(labels).strip()
    all_text_ids.append(_idx)
    all_text_labels.append(formatted_labels)
    print(_idx)
    print("text: {}".format(_text))
    print("labels: {}".format(formatted_labels))

submission_columns = ["ID", "CORE RELATIONS"]
submission_df = pd.DataFrame(columns=submission_columns, data={"ID": all_text_ids, "CORE RELATIONS": all_text_labels})
print(submission_df)
submission_df.to_csv(args.submission_path, index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1960: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 0
# text: star of thor
# labels: movie.starring.actor
# 1
# text: who is in the movie the campaign
# labels: movie.starring.actor
# 2
# text: list the cast of the movie the campaign
# labels: movie.starring.actor
# 3
# text: who was in twilight
# labels: movie.starring.actor
# 4
# text: who is in vulguria
# labels: movie.starring.actor
# 5
# text: actor from lost
# labels: movie.starring.actor
# 6
# text: who played in the movie rocky
# labels: movie.starring.actor
# 7
# text: who played in the movie captain america
# labels: movie.starring.actor
# 8
# text: cast and crew for in july
# labels: movie.starring.actor
# 9
# text: who is in movie in july
# labels: movie.starring.actor
# 10
# text: who's in star wars episode four
# labels: movie.starring.actor
# 11
# text: who was in apollo thirteen
# labels: movie.starring.actor
# 12
# text: who was apollo thirteen 's cast
# labels: movie.starring.actor
# 13
# text: search for information about the cast and crew of appolo thirteen
# labels: movie.starring.actor
# 14
# text: i would like to know more about the cast and crew of the movie apollo thirteen
# labels: movie.starring.actor
# 15
# text: who starred in the avengers
# labels: movie.starring.actor
# 16
# text: cast for finding nemo
# labels: movie.starring.actor
# 17
# text: actor from lassie
# labels: movie.starring.actor
# 18
# text: list actors in the movie midnight cowboy
# labels: movie.starring.actor
# 19
# text: dirty dancing actors
# labels: movie.starring.actor
# 20
# text: who are cast and crew of dirty dancing
# labels: movie.starring.actor
# 21
# text: who was in hitch
# labels: movie.starring.actor
# 22
# text: who is in the cast of hitch
# labels: movie.starring.actor
# 23
# text: star of facts of life
# labels: movie.starring.actor
# 24
# text: show me movie credits
# labels: movie.starring.actor
# 25
# text: who does the voices for the movie
# labels:
# 26
# text: find movie actors
# labels:
# 27
# text: show credits - forager
# labels: movie.starring.actor
# 28
# text: star of modern family
# labels: movie.starring.actor
# 29
# text: look up information about the cast crew of go
# labels: movie.starring.actor
# 30
# text: find information about the cast and crew of go
# labels: movie.starring.actor
# 31
# text: who was in the cast of go
# labels: movie.starring.actor
# 32
# text: can you find the lead actor in pretty women
# labels: movie.starring.actor
# 33
# text: what are the actors names and parts in finding nemo
# labels: movie.starring.actor
# 34
# text: searching for names of crew members of appollo thirteen
# labels: movie.starring.actor
# 35
# text: budget for dark knight
# labels: movie.estimated_budget
# 36
# text: what was the budget for the godfather
# labels: movie.estimated_budget
# 37
# text: budget for twilight
# labels: movie.estimated_budget
# 38
# text: please look up the budget of step up
# labels: movie.estimated_budget
# 39
# text: budget for titanic the movie
# labels: movie.estimated_budget
# 40
# text: what was the budget for the movie titanic
# labels: movie.estimated_budget
# 41
# text: budget for iron man 2
# labels: movie.estimated_budget
# 42
# text: please tell me how much was the budget for avatar
# labels: movie.estimated_budget
# 43
# text: how much money did they spend to make avatar
# labels: movie.gross_revenue movie.estimated_budget
# 44
# text: avatar 's budget
# labels: movie.estimated_budget
# 45
# text: how much did avatar take in
# labels:
# 46
# text: please show me what the budget was for avatar
# labels: movie.estimated_budget
# 47
# text: what was the budget for the avatar movie
# labels: movie.estimated_budget
# 48
# text: can you tell me the budget of the movie avatar
# labels: movie.estimated_budget
# 49
# text: total budget for the movie avatar
# labels: movie.estimated_budget
# 50
# text: what was the budget for batman begins
# labels: movie.estimated_budget
# 51
# text: what was the budget for the avengers
# labels: movie.estimated_budget
# 52
# text: what was the budget for gone with the wind
# labels: movie.estimated_budget
# 53
# text: what was spent on my big fat greek wedding
# labels: movie.production_companies
# 54
# text: what was pretty woman s budget
# labels: movie.estimated_budget
# 55
# text: what was the budget for spaceballs
# labels: movie.estimated_budget
# 56
# text: how many movies has kevin bacon been the lead actor in
# labels: movie.starring.actor
# 57
# text: how many star wars movies are there
# labels:
# 58
# text: how many movies are rated g
# labels: movie.rating
# 59
# text: spain has how many movies
# labels:
# 60
# text: how many movies has kristen stewart starred in
# labels: movie.starring.actor
# 61
# text: how many movies has robert wise directed
# labels: movie.directed_by
# 62
# text: how many movies did alfred hitchcock direct
# labels: movie.directed_by
# 63
# text: how many movies has paramount done
# labels: movie.production_companies
# 64
# text: i would like to know the name of the country from where the movie kati patang comes
# labels: movie.country
# 65
# text: what country is bullhead
# labels: movie.country
# 66
# text: what country made black swan
# labels: movie.country
# 67
# text: what country was black swan from
# labels: movie.country
# 68
# text: what country was the movie made
# labels: movie.country
# 69
# text: what country did deep blue sea come from
# labels: movie.country
# 70
# text: origin of titanic
# labels: movie.country
# 71
# text: origin of king lear
# labels: movie.country
# 72
# text: when will top gun be released
# labels: movie.initial_release_date
# 73
# text: release year and date for casino
# labels: movie.initial_release_date
# 74
# text: when did will ferrell begin acting
# labels: movie.initial_release_date
# 75
# text: show me when 24 will be released
# labels: movie.initial_release_date
# 76
# text: can i have release date of movie
# labels: movie.initial_release_date
# 77
# text: movie's release date
# labels: movie.initial_release_date
# 78
# text: show me when the movie was made
# labels: movie.initial_release_date
# 79
# text: when the movie titanic was released
# labels: movie.initial_release_date
# 80
# text: what year did the italian movie roman holiday come out
# labels: movie.initial_release_date movie.language
# 81
# text: can you please search for release date for karate kid
# labels: movie.initial_release_date
# 82
# text: karate kid release date please
# labels: movie.initial_release_date
# 83
# text: when was dirty dancing released
# labels: movie.initial_release_date
# 84
# text: when was spaceballs released
# labels: movie.initial_release_date
# 85
# text: when was batman released
# labels: movie.initial_release_date
# 86
# text: when was pretty woman released
# labels: movie.initial_release_date
# 87
# text: when was men in black released
# labels: movie.initial_release_date
# 88
# text: when did kristen stewart start acting
# labels: movie.initial_release_date
# 89
# text: when is possessed going to be released
# labels: movie.initial_release_date
# 90
# text: when was resident evil released
# labels: movie.initial_release_date
# 91
# text: release date for finding nemo
# labels: movie.initial_release_date
# 92
# text: when was finding nemo released
# labels: movie.initial_release_date
# 93
# text: release date of hum tum
# labels: movie.initial_release_date
# 94
# text: when was freedom writers released
# labels: movie.initial_release_date
# 95
# text: when was avatar released
# labels: movie.initial_release_date
# 96
# text: when did avatar released
# labels: movie.initial_release_date
# 97
# text: i would like to know the release date of the movie avatar
# labels: movie.initial_release_date
# 98
# text: can you tell me when was the movie avatar released
# labels: movie.initial_release_date
# 99
# text: when was date night released
# labels: movie.initial_release_date
# 100
# text: when did black swan come out
# labels: movie.initial_release_date
# 101
# text: when did avergers come out
# labels: movie.initial_release_date
# 102
# text: what date did the amazing spiderman show for the 1st time
# labels: movie.initial_release_date
# 103
# text: what is the release date of vulgaria
# labels: movie.initial_release_date
# 104
# text: when the movie the godfather was released
# labels: movie.initial_release_date
# 105
# text: when does looper come out
# labels: movie.initial_release_date
# 106
# text: can you tell me the release date of the movie barfi
# labels: movie.initial_release_date
# 107
# text: what date did the movie heroine come out
# labels: movie.initial_release_date
# 108
# text: when did the house at the end of the street hit theaters
# labels: movie.initial_release_date
# 109
# text: what day is fun size coming out
# labels: movie.initial_release_date
# 110
# text: what day will django unchained come out
# labels: movie.initial_release_date
# 111
# text: when will i be able to view iron man 3
# labels: movie.initial_release_date
# 112
# text: on what date will iron man 3 be released
# labels: movie.initial_release_date
# 113
# text: who directed gone with the wind
# labels: movie.directed_by
# 114
# text: who was the director for black swan
# labels: movie.directed_by
# 115
# text: tell me the directed of black swan
# labels: movie.directed_by
# 116
# text: who is the director of sleepless in seattle
# labels: movie.directed_by
# 117
# text: find who the director was in men in black 3
# labels: movie.directed_by
# 118
# text: locate the director who created the movie men in black 3
# labels: movie.directed_by
# 119
# text: director of titanic
# labels: movie.directed_by
# 120
# text: titanic director
# labels: movie.directed_by
# 121
# text: avengers movie director
# labels: movie.directed_by
# 122
# text: dirctor of movie avengers
# labels:
# 123
# text: who was the director for nacho libre
# labels: movie.directed_by
# 124
# text: director for big
# labels: movie.directed_by
# 125
# text: who was the director of welcome to the dollhouse
# labels: movie.directed_by
# 126
# text: who directed the movie house at the end of the at the street
# labels: movie.directed_by
# 127
# text: who was the director of the movie toy story
# labels: movie.directed_by
# 128
# text: list director gilda
# labels: movie.directed_by
# 129
# text: who directed field of dreams
# labels: movie.directed_by
# 130
# text: who is the second director on finding nemo
# labels: movie.directed_by
# 131
# text: find director of finding nemo
# labels: movie.directed_by
# 132
# text: who directed finding nemo
# labels: movie.directed_by
# 133
# text: finding nemo directed by who
# labels: movie.directed_by
# 134
# text: director of finding nemo
# labels: movie.directed_by
# 135
# text: who directed hitch
# labels: movie.directed_by
# 136
# text: i want to know who is the director of the movie batman
# labels: movie.directed_by
# 137
# text: who is director of the words
# labels: movie.directed_by
# 138
# text: who directed million dollar baby
# labels: movie.directed_by
# 139
# text: who was the guy that directed moneyball
# labels: movie.directed_by
# 140
# text: who did twilight
# labels: movie.directed_by
# 141
# text: twilight director
# labels: movie.directed_by
# 142
# text: who directed twilight
# labels: movie.directed_by
# 143
# text: who directed twilight
# labels: movie.directed_by
# 144
# text: who is the director of hum tum
# labels: movie.directed_by
# 145
# text: look for the director of step up
# labels: movie.directed_by
# 146
# text: please find the director of freedom writers
# labels: movie.directed_by
# 147
# text: find the director of freedom writers
# labels: movie.directed_by
# 148
# text: look up the director of freedom writers
# labels: movie.directed_by
# 149
# text: find the director of freedom writers
# labels: movie.directed_by
# 150
# text: who directed baby mama
# labels: movie.directed_by
# 151
# text: godfather director
# labels: movie.directed_by
# 152
# text: show me who directed the sound of music
# labels: movie.directed_by
# 153
# text: who directed the sound of music
# labels: movie.directed_by
# 154
# text: who directed the sound of music
# labels: movie.directed_by
# 155
# text: find the name of the director of return
# labels: movie.directed_by
# 156
# text: show movie avengers director name
# labels: movie.directed_by
# 157
# text: name the director in sleepless in seattle
# labels: movie.directed_by
# 158
# text: what 's the genre for black swan
# labels: movie.genre
# 159
# text: what is black swan 's genre
# labels: movie.genre
# 160
# text: what genre is parenthood
# labels: movie.genre
# 161
# text: what kind of movie is parenthood
# labels: movie.genre
# 162
# text: genre for pride and prejudice
# labels: movie.genre
# 163
# text: can you tell me the genre of the movie lawless
# labels: movie.genre
# 164
# text: show me what genre does movie lawless belongs to
# labels: movie.genre
# 165
# text: genre for snow white and the huntsman
# labels: movie.initial_release_date
# 166
# text: what is the movie type
# labels: movie.genre
# 167
# text: what's the genre of rushmore
# labels: movie.genre
# 168
# text: get the genre of welcome to the dollhouse
# labels: movie.genre
# 169
# text: i want to find the genre freedom writers is in
# labels: movie.genre
# 170
# text: what genre is freedom writers in
# labels: movie.genre
# 171
# text: genre for batman
# labels: movie.genre
# 172
# text: give me the genre of the movie avatar
# labels: movie.genre
# 173
# text: i would like to know the genre of the movie avatar
# labels: movie.genre
# 174
# text: genre for bad teacher
# labels: movie.genre
# 175
# text: can you tell me pretty girl the movie 's genre
# labels: movie.genre
# 176
# text: what genre is the movie pitch perfect
# labels: movie.genre
# 177
# text: in what language is this movie
# labels: movie.language
# 178
# text: what language is this movie
# labels: movie.language
# 179
# text: what language is the movie hero in
# labels: movie.language
# 180
# text: language of king lear
# labels: movie.language
# 181
# text: language of casa blanca
# labels: movie.language
# 182
# text: what language is head on in
# labels: movie.language
# 183
# text: language of spanglish
# labels: movie.language
# 184
# text: find out what language the father of my children is in
# labels: movie.language
# 185
# text: i am intersted in viewing belle what foreign language is the movie available in
# labels: movie.language
# 186
# text: i need to find out about names of some japanese movies
# labels: movie.language movie.country
# 187
# text: can you tell me names of some japanese movies
# labels: movie.language movie.country
# 188
# text: ron howard name some of the movies he produce
# labels: movie.produced_by
# 189
# text: tell me the names of the movies produced by william packer
# labels: movie.produced_by
# 190
# text: about life is beautiful
# labels:
# 191
# text: show me info on life is beautiful
# labels:
# 192
# text: find old movies
# labels:
# 193
# text: find movie ratings
# labels: movie.rating
# 194
# text: find newly released movies in spanish
# labels: movie.language
# 195
# text: was bill paxton in the movie apollo thirteen
# labels: movie.starring.actor
# 196
# text: was kevin bacon in the movie apollo thirteen
# labels: movie.starring.actor
# 197
# text: find movies about dancing
# labels: movie.subjects
# 198
# text: search for movies about dancing
# labels: movie.subjects
# 199
# text: show will ferrell films
# labels: movie.starring.actor
# 200
# text: will ferrell movies
# labels: movie.starring.actor
# 201
# text: what movies has will ferrell appeared in
# labels: movie.starring.actor
# 202
# text: find russian movies
# labels: movie.language movie.country
# 203
# text: show me the movie pretty women so i can see who starred in the movie
# labels: movie.starring.actor
# 204
# text: feral
# labels:
# 205
# text: the movie is called big
# labels:
# 206
# text: will smith acting carrer
# labels:
# 207
# text: how many movies did peter jackson do
# labels:
# 208
# text: movies and gross payment
# labels:
# 209
# text: search for tim burton movies in french
# labels: movie.language
# 210
# text: exhibit all details of original finding nemo movie
# labels: movie.initial_release_date
# 211
# text: finding nemo movie
# labels:
# 212
# text: find the movie finding nemo
# labels:
# 213
# text: i am looking for information on the movie finding nemo
# labels:
# 214
# text: show me details for the movie finding nemo
# labels:
# 215
# text: what did andrew stanton direct
# labels: movie.directed_by
# 216
# text: show me some other movies directed by andrew stanton
# labels: movie.directed_by
# 217
# text: display albert brooks movie
# labels:
# 218
# text: show a movie with albert brooks in the cast
# labels: movie.starring.actor
# 219
# text: what other films has sergio leone directed
# labels: movie.directed_by
# 220
# text: what movies has george harrison produced
# labels: movie.produced_by
# 221
# text: what has charlie sheen starred in
# labels: movie.starring.actor
# 222
# text: please find the movies in which clive owen has appeared
# labels: movie.starring.actor
# 223
# text: in which movies has clive owen appear
# labels: movie.starring.actor
# 224
# text: spike lee directed what movie
# labels: movie.directed_by
# 225
# text: search for movies directed by spike lee
# labels: movie.directed_by
# 226
# text: movie release dates
# labels: movie.initial_release_date
# 227
# text: director information for movies
# labels: movie.directed_by
# 228
# text: movies by director
# labels: movie.directed_by
# 229
# text: please list all movies not rated pg
# labels: movie.rating
# 230
# text: find movies
# labels:
# 231
# text: i want a list of english speaking movies
# labels: movie.language
# 232
# text: a list of movies made in america
# labels: movie.country
# 233
# text: are there any movies produced in the united states
# labels: movie.country
# 234
# text: show english movies
# labels: movie.language
# 235
# text: search english movies
# labels: movie.language
# 236
# text: comedy
# labels: movie.genre
# 237
# text: find a comedy
# labels: movie.genre
# 238
# text: watch comedy movies
# labels: movie.genre
# 239
# text: get horror films
# labels: movie.genre
# 240
# text: show me horror movies
# labels: movie.genre
# 241
# text: i want to see a listing of horror movies
# labels: movie.genre
# 242
# text: show actor bruce willis movies
# labels: movie.starring.actor
# 243
# text: which movies did bruce willis star in
# labels: movie.starring.actor
# 244
# text: list movies with bruce willis
# labels: movie.starring.actor
# 245
# text: show me movies made in canada
# labels: movie.country
# 246
# text: can i watch a canadian film
# labels:
# 247
# text: see canadian movies
# labels: movie.country
# 248
# text: search for information about canadian movies
# labels: movie.country
# 249
# text: I'd like to see some italian films
# labels: movie.language movie.country
# 250
# text: show me something italian - made
# labels: movie.language movie.country
# 251
# text: i want to see a movie from spain
# labels: movie.country
# 252
# text: find movies from spain
# labels: movie.country
# 253
# text: spain country movies
# labels: movie.country
# 254
# text: display a list of spanish films
# labels: movie.language movie.country
# 255
# text: spanish movie listing
# labels: movie.language movie.country
# 256
# text: spanish movies
# labels: movie.language movie.country
# 257
# text: find actors in movies
# labels: movie.starring.actor
# 258
# text: search by actors
# labels:
# 259
# text: find some romantic movies
# labels: movie.genre
# 260
# text: i want to see a movie in french
# labels: movie.language
# 261
# text: gwyneth paltrow movies
# labels:
# 262
# text: find movies with quentin tarantino as director
# labels: movie.directed_by
# 263
# text: england movies
# labels: movie.country
# 264
# text: england movies please
# labels: movie.country
# 265
# text: find david tennant movies
# labels:
# 266
# text: show me what richard lester directed
# labels: movie.directed_by
# 267
# text: get films in hindi
# labels: movie.language
# 268
# text: show me movies from india
# labels: movie.country
# 269
# text: what is a british horror movie
# labels: movie.genre
# 270
# text: i want to watch an r rated comedy
# labels: movie.rating
# 271
# text: list of french language comedies
# labels: movie.language movie.genre
# 272
# text: look for dirty dancing movie with jennifer grey
# labels:
# 273
# text: tell me in detail about the movie dirty dancing
# labels:
# 274
# text: tell about movie dirty dancing
# labels:
# 275
# text: can i see a list of bette midler movies
# labels: movie.starring.actor
# 276
# text: list of movies starring bette midler
# labels: movie.starring.actor
# 277
# text: show me all of anne hathaway 's movies
# labels: movie.starring.actor
# 278
# text: what movies has sandra bullock produced
# labels: movie.produced_by
# 279
# text: find me movies from portugal
# labels: movie.country
# 280
# text: what movies has robert redford been in
# labels: movie.starring.actor
# 281
# text: dirty dancing info
# labels:
# 282
# text: dirty dancing
# labels:
# 283
# text: give a short bio for dirty dancing
# labels:
# 284
# text: about dirty dancing
# labels:
# 285
# text: movies from japan
# labels: movie.country
# 286
# text: show movies from japan
# labels: movie.country
# 287
# text: list japanese movies
# labels: movie.language movie.country
# 288
# text: show me japanese movies
# labels: movie.language movie.country
# 289
# text: give me a list of some japanese movies
# labels: movie.language movie.country
# 290
# text: give me a list of japanese movies
# labels: movie.language movie.country
# 291
# text: japanese movies
# labels: movie.language movie.country
# 292
# text: show me japanese language movies
# labels: movie.language
# 293
# text: which films are spoken in japanese
# labels: movie.language
# 294
# text: miramax films only
# labels: movie.production_companies
# 295
# text: show movies by miramax
# labels: movie.production_companies
# 296
# text: search sandra bullock movies
# labels: movie.starring.actor
# 297
# text: watch sandra bullock movies
# labels: movie.starring.actor
# 298
# text: find movies about vampires
# labels: movie.subjects
# 299
# text: find movies having vampires
# labels: movie.subjects
# 300
# text: will smith movies
# labels: movie.starring.actor
# 301
# text: cars movie
# labels:
# 302
# text: what movies did darla anderson produce
# labels: movie.produced_by
# 303
# text: what films are made by paramount
# labels: movie.production_companies
# 304
# text: show me movies by paramount
# labels: movie.production_companies
# 305
# text: what movies has paramount released
# labels: movie.production_companies
# 306
# text: show all movies from turkey
# labels: movie.country
# 307
# text: show me movies produced by bruce lee
# labels: movie.produced_by
# 308
# text: is parenthood a drama
# labels: movie.genre
# 309
# text: i want to see an kevin james film tonight
# labels:
# 310
# text: find films from china
# labels: movie.country
# 311
# text: get films from china
# labels: movie.country
# 312
# text: i'd like to watch a movie made in china
# labels: movie.country
# 313
# text: list some movies from china
# labels: movie.country
# 314
# text: chinese films
# labels: movie.language movie.country
# 315
# text: show me other chinese movies
# labels: movie.language movie.country
# 316
# text: show me chinese movies
# labels: movie.language movie.country
# 317
# text: what movies have a pg-13 rating
# labels: movie.rating
# 318
# text: please list movies that are rated pg-13
# labels: movie.rating
# 319
# text: i need a g rating so i can take the kids
# labels: movie.rating
# 320
# text: find a g rated movie
# labels: movie.rating
# 321
# text: find g movies
# labels: movie.rating
# 322
# text: find g movies
# labels: movie.rating
# 323
# text: i want rated g movies
# labels: movie.rating
# 324
# text: look up g rated movies
# labels: movie.rating
# 325
# text: i am searching for any g rated movies for my children to view
# labels: movie.rating
# 326
# text: rated g movies for family watching
# labels: movie.rating
# 327
# text: find g rated movies
# labels: movie.rating
# 328
# text: are there any movies rated g playing
# labels: movie.rating
# 329
# text: i want to see movies rated g
# labels: movie.rating
# 330
# text: find movies rated g
# labels: movie.rating
# 331
# text: show me movies with g rating
# labels: movie.rating
# 332
# text: did robert wise direct any other musicals
# labels: movie.directed_by
# 333
# text: bruce lee produced movie listing
# labels: movie.produced_by
# 334
# text: what was the last movie made by robert wise
# labels: movie.initial_release_date movie.directed_by
# 335
# text: find movies produced by mgm
# labels: movie.production_companies
# 336
# text: show me british made movies
# labels: movie.country
# 337
# text: movies from the uk
# labels: movie.country
# 338
# text: find me movies from the uk
# labels: movie.country
# 339
# text: can you list ron howard movie production
# labels:
# 340
# text: i need to know the movies produce by ron howard
# labels: movie.produced_by
# 341
# text: did clint eastwood direct any other movies besides million dollar baby
# labels: movie.directed_by
# 342
# text: find movies directed by clint eastwood
# labels: movie.directed_by
# 343
# text: what movies have been directed by clint eastwood
# labels: movie.directed_by
# 344
# text: list all movies that were directed by clint eastwood
# labels: movie.directed_by
# 345
# text: what movies has clint eastwood directed
# labels: movie.directed_by
# 346
# text: show movies directed by clint eastwood
# labels: movie.directed_by
# 347
# text: find all films by stanley kubrick
# labels: movie.directed_by
# 348
# text: i want to select the option to search for movies produced by stephen spielberg
# labels: movie.produced_by
# 349
# text: i would like to search for movies produced by stephen speilberg
# labels: movie.produced_by
# 350
# text: show me japanese horror movies
# labels: movie.language movie.genre movie.country
# 351
# text: i would like to see movies ron howard directed
# labels: movie.directed_by
# 352
# text: movies by stephen spielberg
# labels: movie.directed_by
# 353
# text: movies by stephen spielberg
# labels: movie.directed_by
# 354
# text: what movies did stephen spielberg direct
# labels: movie.directed_by
# 355
# text: list steven spielberg movies
# labels: movie.directed_by
# 356
# text: steven spielberg movie
# labels: movie.directed_by
# 357
# text: steven spielberg movies please
# labels: movie.directed_by
# 358
# text: directed by steven spielberg
# labels: movie.directed_by
# 359
# text: find the steven spielberg movies
# labels: movie.directed_by
# 360
# text: find movies from steven spielberg
# labels: movie.directed_by
# 361
# text: i would like to watch a movie directed by eddie murphy
# labels: movie.directed_by
# 362
# text: the camp
# labels:
# 363
# text: watch sandra bullock the blind side
# labels: movie.starring.actor
# 364
# text: i want to see movies with hugh jackman
# labels: movie.starring.actor
# 365
# text: list movies with kevin spacey
# labels: movie.starring.actor
# 366
# text: look for movies from france
# labels: movie.country
# 367
# text: can you show me movies that were made in france
# labels: movie.country
# 368
# text: find me any movies that were made in france
# labels: movie.country
# 369
# text: french movies please
# labels: movie.language movie.country
# 370
# text: french movies
# labels: movie.language movie.country
# 371
# text: find movies produced by
# labels: movie.produced_by
# 372
# text: movies by producers
# labels: movie.produced_by
# 373
# text: display movies produced by
# labels: movie.produced_by
# 374
# text: find movies produced by mosfilm
# labels: movie.production_companies
# 375
# text: what was kristen stewart 's first movie
# labels: movie.starring.actor movie.initial_release_date
# 376
# text: get me movies directed by miranda july
# labels: movie.directed_by
# 377
# text: tom hanks movies
# labels: movie.starring.actor
# 378
# text: show me movies with tom hanks
# labels: movie.starring.actor
# 379
# text: i am trying to find a list of movies with tom hanks
# labels: movie.starring.actor
# 380
# text: provide movies directed by oliver stone please
# labels: movie.directed_by
# 381
# text: i want to look for movies produced by albert ruddy
# labels: movie.produced_by
# 382
# text: what are all of the movies produced by albert ruddy
# labels: movie.produced_by
# 383
# text: movies produced by yash chopra
# labels: movie.produced_by
# 384
# text: what did brad pitt porduce
# labels: movie.starring.actor
# 385
# text: bring up all brad pitt produced movies
# labels: movie.produced_by
# 386
# text: show all movies that penny marshall directed
# labels: movie.directed_by
# 387
# text: i need a list of all the movies directed by james cameron
# labels: movie.directed_by
# 388
# text: give me a list of all the movies directed by james cameron
# labels: movie.directed_by
# 389
# text: james cameron movies produced
# labels: movie.produced_by
# 390
# text: movies produced by james cameron
# labels: movie.produced_by
# 391
# text: what films have been produced by warner bros.
# labels: movie.production_companies
# 392
# text: find movies produced by warner bros.
# labels: movie.production_companies
# 393
# text: what movies have been produced by warner bros.
# labels: movie.production_companies
# 394
# text: show me movies by wb
# labels:
# 395
# text: give me information about finding nemo
# labels:
# 396
# text: i want information about finding nemo
# labels:
# 397
# text: show me finding nemo
# labels:
# 398
# text: finding nemo bing
# labels:
# 399
# text: search finding nemo
# labels:
# 400
# text: show information page for finding nemo
# labels:
# 401
# text: the campaign information
# labels:
# 402
# text: more information on apallo thirteen
# labels:
# 403
# text: research apollo thirteen
# labels:
# 404
# text: has kristen stewart starred in movies other than twilight
# labels: movie.starring.actor
# 405
# text: show me kristen stewart movies
# labels: movie.starring.actor
# 406
# text: what movies has kristen stewarted starred in
# labels: movie.starring.actor
# 407
# text: lionsgate movies
# labels: movie.production_companies
# 408
# text: show lionsgate movies
# labels: movie.production_companies
# 409
# text: show movies made by production lionsgate
# labels: movie.production_companies
# 410
# text: give me something by charles vidor
# labels: movie.directed_by
# 411
# text: show charles vidor movie
# labels: movie.directed_by
# 412
# text: what film did charles vidor direct
# labels: movie.directed_by
# 413
# text: which movies have been made outside the united states
# labels: movie.country
# 414
# text: find me nigeria movies
# labels:
# 415
# text: display 7 arts movies
# labels: movie.production_companies
# 416
# text: korean movie
# labels: movie.language movie.country
# 417
# text: what other movies did roberto benigni star in
# labels: movie.starring.actor
# 418
# text: i want to see movies starring denzel washington please
# labels: movie.starring.actor
# 419
# text: list the kareena 's movie
# labels: movie.starring.actor
# 420
# text: i want to watch a drama made in turkey
# labels: movie.genre movie.country
# 421
# text: jennifer lopez played in what movies
# labels: movie.starring.actor
# 422
# text: show me all of the movies directed by woody allen
# labels: movie.directed_by
# 423
# text: show robert wise movies
# labels: movie.directed_by
# 424
# text: want to see robert wise movies
# labels: movie.directed_by
# 425
# text: what movies has robert wise directed
# labels: movie.directed_by
# 426
# text: what movies have robert wise directed
# labels: movie.directed_by
# 427
# text: where can i find a list of movies produced by chris nolan
# labels: movie.produced_by
# 428
# text: what movies has brad pitt been in
# labels: movie.starring.actor
# 429
# text: what are the movies brad pitt had been in
# labels: movie.starring.actor
# 430
# text: what are some movies with brad pitt
# labels: movie.starring.actor
# 431
# text: find an r rated movie
# labels: movie.rating
# 432
# text: show me r rated movies
# labels: movie.rating
# 433
# text: give me a list of r rated movies
# labels: movie.rating
# 434
# text: look up r rated movies
# labels: movie.rating
# 435
# text: i want only r rated movies
# labels: movie.rating
# 436
# text: i want to see a list of rated r movies
# labels: movie.rating
# 437
# text: show me only movies with a rating of r
# labels: movie.rating
# 438
# text: please look for movies with an r rating
# labels: movie.rating
# 439
# text: show me movies rated r
# labels: movie.rating
# 440
# text: look for movies with an r rating
# labels: movie.rating
# 441
# text: give me a list of all movies that are rated r
# labels: movie.rating
# 442
# text: i want to watch movies from norway
# labels: movie.country
# 443
# text: can i have a list of spanish speaking movies
# labels: movie.language
# 444
# text: show me movies made in mexico
# labels: movie.country
# 445
# text: show me the movie pot zombies
# labels: movie.subjects
# 446
# text: what movies have zombies in them
# labels: movie.subjects
# 447
# text: show me movies about zombies
# labels: movie.subjects
# 448
# text: show me movies about zombies
# labels: movie.subjects
# 449
# text: show me ones by david fincher
# labels:
# 450
# text: show ridley scott 's filmography
# labels: movie.directed_by
# 451
# text: find ridley scott movies
# labels:
# 452
# text: can you show me movies directed by ridley scott
# labels: movie.directed_by
# 453
# text: list german movies
# labels: movie.language movie.country
# 454
# text: german movies
# labels: movie.language movie.country
# 455
# text: find action films
# labels: movie.genre
# 456
# text: find some action movies
# labels: movie.genre
# 457
# text: list dredd movie
# labels:
# 458
# text: show me george lucas movies
# labels:
# 459
# text: find movies directed by george lucas
# labels: movie.directed_by
# 460
# text: produced by
# labels: movie.produced_by
# 461
# text: please find movies produced by morgan freeman
# labels: movie.produced_by
# 462
# text: please look up movies produced by morgan freeman
# labels: movie.produced_by
# 463
# text: search for movies produced by morgan freeman
# labels: movie.produced_by
# 464
# text: find movies produced by morgan freeman
# labels: movie.produced_by
# 465
# text: look up movies produced by morgan freeman
# labels: movie.produced_by
# 466
# text: what movies has meryl streep starred in
# labels: movie.starring.actor
# 467
# text: show me the movies directed by the director of this movie
# labels: movie.directed_by
# 468
# text: i want to see movies made in russia
# labels: movie.country
# 469
# text: look up star wars four movie
# labels:
# 470
# text: display all details about star wars-a new hope movie
# labels:
# 471
# text: get all details about star wars-a new hope movie
# labels:
# 472
# text: star wars episode four
# labels:
# 473
# text: i want star wars four main page
# labels:
# 474
# text: search star wars four
# labels:
# 475
# text: find me tons of info related to star wars four
# labels:
# 476
# text: get details of in july movie
# labels:
# 477
# text: find details of in july movie
# labels:
# 478
# text: show details of in july movie
# labels:
# 479
# text: tell me about in july movie
# labels:
# 480
# text: look up the movie in july
# labels:
# 481
# text: display information for the movie title in july
# labels:
# 482
# text: movie in july data
# labels:
# 483
# text: where can i find the movie aankhen in hindi
# labels: movie.language
# 484
# text: display julia roberts films
# labels:
# 485
# text: list the movies that have the actress angelina jolie
# labels: movie.starring.actor
# 486
# text: dustin hoffman movies
# labels:
# 487
# text: what movies did david ayer direct
# labels: movie.directed_by
# 488
# text: i would like to view movies produced by clint eastwood
# labels: movie.produced_by
# 489
# text: list all movies about horses
# labels: movie.subjects
# 490
# text: find all johnny depp movies
# labels:
# 491
# text: search by director
# labels: movie.directed_by
# 492
# text: search by director
# labels: movie.directed_by
# 493
# text: is there any upcoming movies from warner brothers
# labels: movie.production_companies
# 494
# text: bring up movies with ice skating in it
# labels: movie.subjects
# 495
# text: find newly released comedies from england
# labels: movie.genre movie.country
# 496
# text: i need info on house at the end of the street
# labels:
# 497
# text: what is the houses at the end of the street about
# labels:
# 498
# text: give me more facts about the movie house at the end of the street in detail
# labels:
# 499
# text: i would like to know in detail about the movie house at the end of the street
# labels:
# 500
# text: display movie information for the film house at the end of the street
# labels:
# 501
# text: films with chinese
# labels: movie.language movie.country
# 502
# text: i want to watch a movie in chinese
# labels: movie.language
# 503
# text: find movies produced and directed by tyler perry
# labels: movie.directed_by
# 504
# text: tom cruise movies please
# labels: movie.starring.actor
# 505
# text: i want tom cruise movies please
# labels: movie.starring.actor
# 506
# text: which movies star tom cruise
# labels: movie.starring.actor
# 507
# text: which movies do tom cruise play in
# labels: movie.starring.actor
# 508
# text: find end of watch
# labels:
# 509
# text: search by genre
# labels: movie.genre
# 510
# text: looking for movies of yash chopra
# labels: movie.directed_by
# 511
# text: find me information about the campaign movie
# labels:
# 512
# text: information for movie the campaign
# labels:
# 513
# text: show me info on the movie the campaign please
# labels:
# 514
# text: i need to see all the details about the movie the campaign
# labels:
# 515
# text: sort all pg movies
# labels: movie.rating
# 516
# text: pg rated movies
# labels: movie.rating
# 517
# text: access a list of pg movies please
# labels: movie.rating
# 518
# text: give me a list of pg movies
# labels: movie.rating
# 519
# text: can you find me a list of pg rated movies to watch
# labels: movie.rating
# 520
# text: show me a list of pg rated movies
# labels: movie.rating
# 521
# text: find movies with a pg rating
# labels: movie.rating
# 522
# text: what movies are pg
# labels: movie.rating
# 523
# text: movies by alfred hitchcock
# labels: movie.directed_by
# 524
# text: what movies did alfred hitchcock make
# labels: movie.directed_by
# 525
# text: watch hitchcook movies
# labels:
# 526
# text: i want to see any current movies starring tom hanks
# labels: movie.starring.actor
# 527
# text: i want a list of recent movies rated pg
# labels: movie.initial_release_date movie.rating
# 528
# text: give me a list of recent movies rated pg
# labels: movie.initial_release_date movie.rating
# 529
# text: ray stark produced what other movies
# labels: movie.produced_by
# 530
# text: what is spielberg 's latest movie
# labels: movie.initial_release_date movie.directed_by
# 531
# text: please find movies directed by tom hanks
# labels: movie.directed_by
# 532
# text: are there any recent movies that are polish speaking
# labels: movie.initial_release_date movie.language
# 533
# text: what movies has tom cruise been in recently
# labels: movie.starring.actor movie.initial_release_date
# 534
# text: search for new movies
# labels: movie.initial_release_date
# 535
# text: search for in july
# labels:
# 536
# text: watch in july online
# labels:
# 537
# text: search for information about lionsgate
# labels:
# 538
# text: lionsgate info
# labels:
# 539
# text: find information about paramount studios
# labels:
# 540
# text: who is ray stark
# labels:
# 541
# text: find information on charles vidor
# labels:
# 542
# text: i want to look up information about tom cruise
# labels:
# 543
# text: can you please search details about will ferrell
# labels:
# 544
# text: will ferrell biography
# labels:
# 545
# text: show will ferrell biography
# labels:
# 546
# text: show me a complete biography of will ferrell
# labels:
# 547
# text: show me information on will ferrell
# labels:
# 548
# text: show me will ferrell 's bio
# labels:
# 549
# text: get info on kristen stewart
# labels:
# 550
# text: does kristen stewart have a personal page
# labels:
# 551
# text: where can i find information about kristen stewart
# labels:
# 552
# text: jennifer aniston bio
# labels:
# 553
# text: i want to see spielberg 's main page
# labels:
# 554
# text: steven spielberg summary
# labels:
# 555
# text: about steven spielberg
# labels:
# 556
# text: find me bio details for steven spielberg
# labels:
# 557
# text: bio for steven spielberg
# labels:
# 558
# text: show me alfred hitchcock
# labels:
# 559
# text: i want more information about alfred hitchock 's biography
# labels:
# 560
# text: all info hitchcock
# labels: movie.directed_by
# 561
# text: find the name of the producer of avatar
# labels: movie.produced_by
# 562
# text: producer hitch
# labels: movie.produced_by
# 563
# text: who produces hitch
# labels: movie.produced_by
# 564
# text: production company for transformers
# labels: movie.production_companies
# 565
# text: what company made et
# labels: movie.production_companies
# 566
# text: what was the production company for et
# labels: movie.production_companies
# 567
# text: who produces cars
# labels: movie.produced_by
# 568
# text: can you find who produced cars
# labels: movie.produced_by
# 569
# text: production company for devil
# labels: movie.production_companies
# 570
# text: who produced the movie steel magnolias
# labels: movie.produced_by
# 571
# text: who produced avatar
# labels: movie.produced_by
# 572
# text: i want to know the producer of avatar
# labels: movie.produced_by
# 573
# text: who produced avatar
# labels: movie.produced_by
# 574
# text: who produced avatar
# labels: movie.produced_by
# 575
# text: avatar producer
# labels: movie.produced_by
# 576
# text: i would like to know who produced the movie avatar
# labels: movie.produced_by
# 577
# text: who produced the movie avatar
# labels: movie.produced_by
# 578
# text: who are the producers for the movie avatar
# labels: movie.produced_by
# 579
# text: what is grease 's producer
# labels: movie.produced_by
# 580
# text: who produced grease
# labels: movie.produced_by
# 581
# text: who produced the movie my big fat greek wedding
# labels: movie.produced_by
# 582
# text: who produced pretty woman
# labels: movie.produced_by
# 583
# text: tell me the producer for the godfather
# labels: movie.produced_by
# 584
# text: the godfather was produced by
# labels: movie.produced_by
# 585
# text: who produced the movie clue
# labels: movie.produced_by
# 586
# text: who produced hotel rwanda
# labels: movie.produced_by
# 587
# text: who produced marley and me
# labels: movie.produced_by
# 588
# text: who produced despicable me
# labels: movie.produced_by
# 589
# text: who is the company that produced the movie inception
# labels: movie.production_companies
# 590
# text: what company developed the movie inception
# labels: movie.production_companies
# 591
# text: find producer of the great debaters
# labels: movie.produced_by
# 592
# text: who produced inception
# labels: movie.produced_by
# 593
# text: provide the name of the company that produced sparkle
# labels: movie.production_companies
# 594
# text: i need to know the company that produced sparkle
# labels: movie.production_companies
# 595
# text: find the producer of look who 's talking
# labels: movie.produced_by
# 596
# text: who produced harlem nights
# labels: movie.produced_by
# 597
# text: find the producer of step up
# labels: movie.produced_by
# 598
# text: please find the producer of freedom writers
# labels: movie.produced_by
# 599
# text: look for the producer of freedom writers
# labels: movie.produced_by
# 600
# text: show me movie rating
# labels: movie.rating
# 601
# text: how much revenue did pretty woman make
# labels: movie.gross_revenue
# 602
# text: earnings for pretty woman
# labels: movie.gross_revenue
# 603
# text: what was the revenue of pretty woman
# labels: movie.gross_revenue
# 604
# text: how much did pretty woman make
# labels: movie.gross_revenue
# 605
# text: what was the gross revenue for the avengers
# labels: movie.gross_revenue
# 606
# text: how much did the avengers make
# labels:
# 607
# text: revenue for the avengers
# labels: movie.gross_revenue
# 608
# text: how much did the dark night generate in revenues
# labels: movie.gross_revenue
# 609
# text: find revenue totals for jurassic park
# labels: movie.gross_revenue
# 610
# text: revenue for independence day
# labels: movie.gross_revenue
# 611
# text: what is the new will ferrell movie about
# labels: movie.initial_release_date
# 612
# text: who played the voice of nemo in finding nemo
# labels: movie.starring.actor movie.starring.character
# 613
# text: who played richie cunningham in happy days
# labels: movie.starring.actor movie.starring.character
# 614
# text: who stars in house at the end of the street
# labels: movie.starring.actor
# 615
# text: show me the cast for the house at the end of the street
# labels: movie.starring.actor
# 616
# text: cast and crew of house at the end of the street
# labels: movie.starring.actor
# 617
# text: ethel actress from i love lucy
# labels: movie.starring.actor
# 618
# text: actress who played ethel on i love lucy
# labels: movie.starring.actor movie.starring.character
# 619
# text: who are the cast members in lord of the rings the two towers
# labels: movie.starring.actor
# 620
# text: who played hawkeye in mash
# labels: movie.starring.actor movie.starring.character
# 621
# text: who played mother in tarkovsky 's mirror
# labels: movie.starring.actor movie.starring.character
# 622
# text: show me the actor of the movie muthyala muggu
# labels: movie.starring.actor
# 623
# text: who are the droids in star wars episode four
# labels: movie.starring.actor
# 624
# text: who was that guy again who was in the avengers
# labels: movie.starring.actor
# 625
# text: which actor played frodo in lord of the rings
# labels: movie.starring.actor
# 626
# text: find the name of the actress who played mother in mirror by andrey tarkovsky
# labels: movie.starring.actor movie.starring.character
# 627
# text: what is the name of the actress who played mother in tarkovsky 's mirror
# labels: movie.starring.actor movie.starring.character
# 628
# text: what is the name of the actor who played todd in the tv show one life to live
# labels: movie.starring.actor
# 629
# text: give me the name of the main actress in platoon
# labels: movie.starring.actor
# 630
# text: what's the name of the mom on seinfeld
# labels: movie.starring.actor
# 631
# text: name the co-star in shoot to kill
# labels: movie.starring.actor
# 632
# text: what is the name of the actor who played atticus finch in to kill a mockingbird
# labels: movie.starring.actor movie.starring.character
# 633
# text: show me the name of the guy who was the father and a lawyer in to kill a mockingbird
# labels: movie.starring.actor
# 634
# text: please provide the cost for producing the deer hunter
# labels: movie.estimated_budget
# 635
# text: what is the budget for epic
# labels: movie.estimated_budget
# 636
# text: search budget for the movie epic
# labels: movie.estimated_budget
# 637
# text: what was the budget for fire proof
# labels: movie.estimated_budget
# 638
# text: what was the budget for fly whele
# labels: movie.estimated_budget
# 639
# text: what was the budget for 1st harry potter movie
# labels: movie.estimated_budget
# 640
# text: how much was spent on shooting the last harry potter film
# labels: movie.estimated_budget
# 641
# text: how much does it cost to produce looper
# labels: movie.estimated_budget
# 642
# text: how much did it cost to produce looper
# labels: movie.estimated_budget
# 643
# text: how much money was spent to produce looper
# labels: movie.estimated_budget
# 644
# text: how much did men in black 3 cost
# labels: movie.estimated_budget
# 645
# text: how much was it to make paranorman
# labels: movie.estimated_budget
# 646
# text: show me the budget to rebel movie
# labels: movie.estimated_budget
# 647
# text: show me the budget for star wars 2
# labels: movie.estimated_budget
# 648
# text: how much did it cost to create the boardwalk empire
# labels: movie.estimated_budget
# 649
# text: show me the budget for expendables 1
# labels: movie.estimated_budget
# 650
# text: what was the budget for finding nemo in 3d
# labels: movie.estimated_budget
# 651
# text: liongate
# labels:
# 652
# text: which country made inchochine
# labels: movie.country
# 653
# text: what country filed les mes
# labels: movie.country
# 654
# text: what country is les mes from
# labels: movie.country
# 655
# text: where was the milk of sorrow made
# labels: movie.country
# 656
# text: what country is shawshank redemption
# labels: movie.country
# 657
# text: what country does the movie thoda pyaar thoda magic comes from
# labels: movie.country
# 658
# text: tell me where the white ribbon came from
# labels: movie.country
# 659
# text: when was the movie barfi! released
# labels: movie.initial_release_date
# 660
# text: what are the dates for the movie barfi!
# labels:
# 661
# text: release date of the new bugs bunny film
# labels: movie.initial_release_date
# 662
# text: what is the release date of evil goes global
# labels: movie.initial_release_date
# 663
# text: what is the release date for jaws 17 in the theaters
# labels: movie.initial_release_date
# 664
# text: what is the release date for jurassic park 4
# labels: movie.initial_release_date
# 665
# text: list release dates for the jurassic park movies
# labels: movie.initial_release_date
# 666
# text: when will the movie omg oh my god be released
# labels: movie.initial_release_date
# 667
# text: when was the lord of the rings movie released
# labels: movie.initial_release_date
# 668
# text: whats paranormal activities release date
# labels: movie.initial_release_date
# 669
# text: when will robocop come out
# labels: movie.initial_release_date
# 670
# text: when was suckerpunch be released
# labels: movie.initial_release_date
# 671
# text: when was the sound of music released
# labels: movie.initial_release_date
# 672
# text: when will twilight breaking dawn part 2 be released
# labels: movie.initial_release_date
# 673
# text: who directed ai
# labels: movie.directed_by
# 674
# text: find the director of downton abbey
# labels: movie.directed_by
# 675
# text: who directed good bad and ugly
# labels: movie.directed_by
# 676
# text: i can't remember who directed star wars
# labels: movie.directed_by
# 677
# text: find the director of to kill a mockingbird
# labels: movie.directed_by
# 678
# text: is amelie in a different language
# labels: movie.language
# 679
# text: what language was amelie filmed in
# labels: movie.language
# 680
# text: what language is the full monty in
# labels: movie.language
# 681
# text: what is ju on 's original language
# labels: movie.language
# 682
# text: what language is secrets and lies in
# labels: movie.language
# 683
# text: give me names of some action movies with a pg thirteen rating
# labels: movie.rating
# 684
# text: show all comedy musicals for twenty twelve
# ...
# labels: movie.starring.actor
# 763
# text: i want to find movies starring the singer mario
# labels: movie.starring.actor
# 764
# text: look for movies with max von sudow
# labels:
# 765
# text: show me movies that have patrick swayze and jennifer grey in them
# labels: movie.starring.actor
# 766
# text: show me movies that star patrick swayze starred in from nineteen eighty seven
# labels: movie.starring.actor
# 767
# text: what is that dancing movie with patrick swayze
# labels: movie.starring.actor
# 768
# text: movies of sharukh khan
# labels:
# 769
# text: movie that tom hanks and kevin becon played in together
# labels: movie.starring.actor
# 770
# text: movies about animals
# labels: movie.subjects
# 771
# text: show me movies about bollywood
# labels: movie.subjects
# 772
# text: chess movies
# labels: movie.subjects
# 773
# text: show me movies on chess
# labels: movie.subjects
# 774
# text: what are some movies about disco
# labels:
# 775
# text: what movies can offer tips on gardening
# labels:
# 776
# text: i want to look up movies about hair
# labels: movie.subjects
# 777
# text: find movies about libraries
# labels: movie.subjects
# 778
# text: find some movies about musicians
# labels: movie.subjects
# 779
# text: can you find movies about preschool boys
# labels: movie.subjects
# 780
# text: look for movies about preschool boys
# labels: movie.subjects
# 781
# text: what films focus on rape and victim 's rights
# labels:
# 782
# text: i would like to know names of some movies on religious issues
# labels: movie.starring.actor
# 783
# text: give me a list of some movies on religious issues
# labels:
# 784
# text: look for movies about school
# labels: movie.subjects
# 785
# text: tell me the names of some soccer movies
# labels:
# 786
# text: what are some time travel movies i can watch
# labels: movie.subjects
# 787
# text: show me movies involving time travel
# labels: movie.subjects
# 788
# text: vampire movies please
# labels:
# 789
# text: list movies with a theme of war in them
# labels: movie.subjects
# 790
# text: show all movies with the theme of war
# labels: movie.subjects
# 791
# text: can you find me some movies about war
# labels: movie.subjects
# 792
# text: i want a list of movies about war
# labels: movie.subjects
# 793
# text: i want movies about war
# labels: movie.subjects
# 794
# text: find movies about world war two
# labels: movie.subjects
# 795
# text: what are some zombie apocalypse movies
# labels: movie.subjects
# 796
# text: search for zombie movies
# labels: movie.subjects
# 797
# text: show me belle in spanish
# labels: movie.language
# 798
# text: is dredd rated r
# labels: movie.rating
# 799
# text: take me to the french version of et
# labels: movie.language
# 800
# text: find et in french
# labels: movie.language
# 801
# text: find fast and furious in japanese
# labels:
# 802
# text: hard day 's night richard lester
# labels:
# 803
# text: information about movie life is beautiful
# labels:
# 804
# text: movie information for life is beautiful
# labels:
# 805
# text: will you please show me info on the movie life is beautiful
# labels:
# 806
# text: can you please show me info on the movie life is beautiful
# labels:
# 807
# text: show me details to the movie life is beautiful
# labels:
# 808
# text: show me info on the movie life is beautiful please
# labels:
# 809
# text: open a page about the movie life is beautiful
# labels:
# 810
# text: is nine fourteen the premiere date for resident evil
# labels: movie.initial_release_date
# 811
# text: select rio in chinese
# labels: movie.language
# 812
# text: find me the first star wars movie info
# labels:
# 813
# text: i need details about the movie star wars:episode four -a new hope
# labels:
# 814
# text: did ray stark produce steel magnolias
# labels:
# 815
# text: is the movie toy story 4 being released next summer
# labels:
# 816
# text: i want to look up information about american movies
# labels:
# 817
# text: chinese foreign film with kungfu
# labels: movie.language movie.country
# 818
# text: french movies for twenty twelve
# labels: movie.language movie.country
# 819
# text: look for russian movies by mosfilm
# labels: movie.language movie.country
# 820
# text: show production company lionsgate
# labels: movie.production_companies
# 821
# text: paramount film studios
# labels:
# 822
# text: i would like to have more information about the producer ray stark
# labels:
# 823
# text: show me details for the director steven spielberg
# labels:
# 824
# text: show me that actor tom cruise
# labels: movie.starring.actor
# 825
# text: i would like information about the actor will ferrell
# labels:
# 826
# text: who produced the movie great debaters
# labels: movie.produced_by
# 827
# text: king 's speech production company
# labels: movie.production_companies
# 828
# text: i wonder who produced star wars
# labels: movie.produced_by
# 829
# text: i can 't remember who produced star wars
# labels: movie.produced_by
# 830
# text: who produced star wars
# labels: movie.produced_by
# 831
# text: movie producers
# labels: movie.produced_by
# 832
# text: how much did end of watch gross
# labels: movie.gross_revenue
# 833
# text: how much did movie earn
# labels:
# 834
# text: show me the earnings for hotel transylvania
# labels: movie.gross_revenue
# 835
# text: what did the movie the house at the end of the steet gross
# labels: movie.gross_revenue
# 836
# text: revenue for iron man 2
# labels: movie.gross_revenue
# 837
# text: what amount of revenue did iron man make
# labels: movie.gross_revenue
# 838
# text: what was the gross revenue of iron man
# labels: movie.gross_revenue
# 839
# text: kahani 's revenue
# labels: movie.gross_revenue
# 840
# text: get the revenue of kahani
# labels: movie.gross_revenue
# 841
# text: revenue looper
# labels: movie.gross_revenue
# 842
# text: how much did looper gross in sales
# labels:
# 843
# text: how much did looper gross
# labels: movie.gross_revenue
# 844
# text: ho much did looper make
# labels: movie.directed_by
# 845
# text: how much money did mr and mrs smith make
# labels: movie.gross_revenue
# 846
# text: how much money did the movie mr and mrs smith make
# labels: movie.gross_revenue
# 847
# text: in the movie mr and mrs smith how much money did the box offfice report
# labels:
# 848
# text: how much money did philadelphia make
# labels: movie.gross_revenue
# 849
# text: i want to know what the revenue for pirates was
# labels: movie.gross_revenue
# 850
# text: how much was made from platoon
# labels: movie.estimated_budget
# 851
# text: what was the gross revenue earned by star wars in its original release
# labels: movie.gross_revenue
# 852
# text: what was the total gross receipts at the box office for the movie star wars
# labels:
# 853
# text: what were the gross receipts for hunger games
# labels: movie.gross_revenue
# 854
# text: tell me how much money tommy boy made
# labels: movie.gross_revenue
# 855
# text: how much revenue did top gun make
# labels: movie.gross_revenue
# 856
# text: tell me the revenue of training day
# labels: movie.gross_revenue
# 857
# text: what is life is beautiful about
# labels:
# 858
# text: show me a list of production companies
# labels:
# 859
# text: find the male actor from grand torino
# labels: movie.starring.actor actor.gender
# 860
# text: who played the female lead in hitch
# labels: movie.starring.actor actor.gender
# 861
# text: find the female actress from shallow hal
# labels: movie.starring.actor actor.gender
# 862
# text: who is in picture three
# labels: movie.starring.actor
# 863
# text: who are the lead actors
# labels:
# 864
# text: how old is jennifer aniston
# labels: person.date_of_birth
# 865
# text: when was will ferrell born
# labels: person.date_of_birth
# 866
# text: where was black swan directed
# labels: movie.country
# 867
# text: where was muriel's wedding shot
# labels: movie.country
# 868
# text: show release date in the usa for the movie little women
# labels: movie.initial_release_date
# 869
# text: show movie description
# labels:
# 870
# text: i'd like to see popular film directors from the nineteen fifty 's through today
# labels:
# 871
# text: best director
# labels:
# 872
# text: best directors of all time
# labels: movie.subjects
# 873
# text: please show me famous film directors
# labels:
# 874
# text: greatest directors
# labels:
# 875
# text: who produced some of the most popular movies
# labels: movie.produced_by
# 876
# text: show me successful movie directors
# labels:
# 877
# text: who produced hotel rwanda cover art
# labels: movie.produced_by
# 878
# text: who's the director
# labels: movie.directed_by
# 879
# text: director's name
# labels: movie.directed_by
# 880
# text: what is the name of a turkish director that produced a drama film
# labels: movie.produced_by
# 881
# text: watch dredd movie
# labels: movie.rating
# 882
# text: see dredd movie
# labels:
# 883
# text: what was the name of an academy award winning russian documentary
# labels: movie.language movie.country
# 884
# text: what movie titles starring meryl streep earned oscar nominations
# labels:
# 885
# text: in search for names of crew members please
# labels: movie.starring.actor
# 886
# text: get me reviews and info about the campaign movie
# labels:
# 887
# text: show me reviews and info for the campaign
# labels:
# 888
# text: what movies that clint eastwood direct that he won the best director oscar for
# labels: movie.directed_by
# 889
# text: what 's hitchcock 's most famous movie
# labels: movie.directed_by
# 890
# text: tell me some of walter f parkes best movies
# labels:
# 891
# text: looking for movies directed by actor number one
# labels: movie.directed_by
# 892
# text: list of movies directed by director three
# labels: movie.directed_by
# 893
# text: show me the film that grossed seven point two million at the box office
# labels:
# 894
# text: show me movies that made over seven million dollars
# labels: movie.country
# 895
# text: show me movies that didn't gross much
# labels:
# 896
# text: i want to see movies from early two thousands
# labels: movie.country
# 897
# text: show last years films by 7 arts
# labels: movie.initial_release_date movie.production_companies
# 898
# text: show all movies that came out nine fourteen twenty twelve
# labels: movie.initial_release_date
# 899
# text: were there any movies released nine fourteen twenty twelve
# labels: movie.initial_release_date
# 900
# text: show me movies from the nineteen seventies
# labels: movie.country
# 901
# text: can you list all movies from twenty twelve with a rating of three stars and up
# labels: movie.rating
# 902
# text: academy award lionsgate movies
# labels: movie.production_companies
# 903
# text: show oscar winning movies by warner brothers
# labels: movie.production_companies
# 904
# text: what movie performance did meryl streep win her best supporting oscar
# labels:
# 905
# text: have any us released movies been filmed on location in the czech republic
# labels: movie.country
# 906
# text: what us release movies have been filmed in the czech republic
# labels: movie.locations movie.country
# 907
# text: list movies set in ireland
# labels:
# 908
# text: show me the movies released in england
# labels:
# 909
# text: what movies are coming out this week in great britain
# labels:
# 910
# text: show me the movies released in nepal
# labels:
# 911
# text: what are the top five french movies of all time
# labels: movie.language movie.country
# 912
# text: what top films have come out of russia
# labels: movie.country
# 913
# text: show me the top movies from spain
# labels: movie.country
# 914
# text: what is the highest rated zombie movie
# labels: movie.gross_revenue movie.rating
# 915
# text: what are highly rated zombie movies i can watch
# labels: movie.rating
# 916
# text: look for popular movies
# labels:
# 917
# text: search for foreign language films
# labels: movie.language
# 918
# text: what is will ferrell famous for
# labels:
# 919
# text: is this a musical
# labels: movie.genre
# 920
# text: hope that the movie is in english
# labels: movie.language
# 921
# text: is this movie in english
# labels: movie.language
# 922
# text: do they speak german in the movie
# labels: movie.language
# 923
# text: is this movie filmed in india
# labels: movie.country
# 924
# text: show all dawn of the dead movies
# labels:
# 925
# text: all of kung fu panda movies
# labels:
# 926
# text: list movies that have time travel in their title
# labels: movie.subjects
# 927
# text: i want to see nine twenty eight release date films from twenty twelve
# labels: movie.initial_release_date
# 928
# text: find information about french movies
# labels: movie.language movie.country
# 929
# text: i need to know more about the life and movies of indian actor dilip kumar
# labels: movie.starring.actor
# 930
# text: what does the miramax logo look like
# labels: movie.production_companies
# 931
# text: show me pictures of martin scorsese
# labels: movie.directed_by
# 932
# text: photos of steven spielberg
# labels:
# 933
# text: i want to see images of will ferrell
# labels:
# 934
# text: show me pictures of woody allen
# labels: movie.directed_by
# 935
# text: what are popular movie producers
# labels: movie.produced_by
# 936
# text: can you give me the producer
# labels:
# 937
# text: i would like to know the rating of the movie avatar
# labels: movie.rating
# 938
# text: what rating is the movie barfi
# labels: movie.rating
# 939
# text: what is finding nemo rated
# labels: movie.rating
# 940
# text: i need to know the rating of grease
# labels: movie.rating
# 941
# text: can you find out what rating the movie grease is
# labels: movie.rating
# 942
# text: what is kids by larry clark rated
# labels: movie.rating
# 943
# text: what rating did marley and me receive
# labels: movie.rating
# 944
# text: what is the rating for mr and mrs smith
# labels: movie.rating
# 945
# text: what rating did resident evil receive
# labels: movie.rating
# 946
# text: rating for snow white and the huntsman
# labels: movie.initial_release_date movie.rating
# 947
# text: what rating is step up
# labels: movie.rating
# 948
# text: look up the rating of the movie step up
# labels: movie.rating
# 949
# text: what rating did the campaign movie get
# labels: movie.rating
# 950
# text: show me the rating for the movie the expendables
# labels: movie.rating
# 951
# text: what is the rating for toy story
# labels: movie.rating
# 952
# text: what is the rating for the movie toy story
# labels: movie.rating
# 953
# text: rating for twilight breaking dawn
# labels: movie.rating
# 954
# text: what was gross revenue for batman begins
# labels: movie.gross_revenue
# 955
# text: how much has black swan brought in
# labels: movie.starring.actor
# 956
# text: find the revenue for downton abbey
# labels: movie.gross_revenue
# 957
# text: find the revenue of edward scissor hands
# labels: movie.gross_revenue
# 958
# text: what is the most a movie made
# labels:
# 959
# text: reviews for dirty dancing
# labels:
# 960
# text: find reviews for dirty dancing
# labels:
# 961
# text: what are reviews for finding nemo
# labels:
# 962
# text: what are the ratings and review on finding nemo
# labels: movie.rating
# 963
# text: reviews for finding nemo
# labels:
# 964
# text: reviews for finding nemo
# labels:
# 965
# text: reviews for finding nemo
# labels:
# 966
# text: reviews for movie
# labels:
# 967
# text: reviews for in july
# labels:
# 968
# text: what are the reviewers saying about star wars episode four
# labels:
# 969
# text: how long is life is beautiful
# labels:
# 970
# text: synopsis for the movie house at the end of the street
# labels:
# 971
# text: synopsis for star wars four
# labels:
# 972
# text: summary of star wars four
# labels:
# 973
# text: finding nemo movie shortcut
# labels:
# 974
# text: show me the trailer for house at the end of the street
# labels:
# 975
# text: life is beatiful shortcut
# labels:
# 976
# text: trailer for star wars a new hope
# labels:
# 977
# text: show resident evil movies with trailers
# labels: movie.starring.actor
# 978
# text: can i see previews for upcoming warner brothers movies
# labels: movie.production_companies
# 979
# text: how many woody allen movies are set in new york city
# labels: movie.initial_release_date movie.directed_by
# 980
# text: how many scorsese films were filmed in france
# labels: movie.locations
#       ID                                CORE RELATIONS
# 0      0                          movie.starring.actor
# 1      1                          movie.starring.actor
# 2      2                          movie.starring.actor
# 3      3                          movie.starring.actor
# 4      4                          movie.starring.actor
# ..   ...                                           ...
# 976  976
# 977  977                          movie.starring.actor
# 978  978                    movie.production_companies
# 979  979  movie.initial_release_date movie.directed_by
# 980  980                               movie.locations
#
# [981 rows x 2 columns]
